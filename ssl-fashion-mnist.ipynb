# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import DataLoader

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\anaconda3\envs\gputest\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\anaconda3\envs\gputest\lib\site-packages (from scikit-learn) (1.23.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\anaconda3\envs\gputest\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\anaconda3\envs\gputest\lib\site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda3\envs\gputest\lib\site-packages (from scikit-learn) (3.4.0)

# %%
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in c:\anaconda3\envs\gputest\lib\site-packages (1.5.1)

# %%
def ResNet18SimCLR():
    resnet = models.resnet18(pretrained=False)
    resnet.fc = nn.Identity()  # Remove the fully connected layer
    return resnet

# %%
def augment(x):
    transform = transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomApply([transforms.ColorJitter(0.8, 0.8, 0.8, 0.2)], p=0.8),
    ])
    x = torch.stack([transform(img) for img in x])
    return x

# %%
def projection_head(x_tuple, hidden_dim=256,device=torch.device("cuda" if torch.cuda.is_available() else "cpu")):
    flattened_tensors = [tensor.flatten(start_dim=1) for tensor in x_tuple]
    # Concatenate the flattened tensors along dimension 1
    concatenated_tensor = torch.cat(flattened_tensors, dim=1)
    projection = nn.Sequential(
        nn.Linear(concatenated_tensor.shape[1], hidden_dim),
        nn.ReLU(inplace=True),
        nn.Linear(hidden_dim, hidden_dim),
    ).to(device)  # Move projection head to the correct device
    return projection(concatenated_tensor)

# %%
def NTXentLoss(z1, z2, temperature=0.5):
    N = z1.size(0)
    z = torch.cat([z1, z2], dim=0)
    sim = torch.mm(z, z.t()) / (torch.norm(z, dim=1, keepdim=True) * torch.norm(z.t(), dim=0, keepdim=True))
    sim = sim / temperature
    sim_exp = torch.exp(sim)
    sim_exp = sim_exp - torch.eye(2 * N, device=z.device)
    sim_1_2 = sim_exp[:N, N:]
    sim_2_1 = sim_exp[N:, :N]
    sim_1_1 = sim_exp[:N, :N]
    sim_2_2 = sim_exp[N:, N:]

    loss = -(torch.log(sim_1_2.sum(dim=1) / (sim_1_1.sum(dim=1) + sim_1_2.sum(dim=1))).mean() +
             torch.log(sim_2_1.sum(dim=1) / (sim_2_1.sum(dim=1) + sim_2_2.sum(dim=1))).mean()) / 2
    return loss

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4)
# Out:
# Files already downloaded and verified

# %%
resnet_model = ResNet18SimCLR().to(device)

# Optimizer
optimizer = optim.Adam(resnet_model.parameters(), lr=3e-4)

# %%
num_epochs = 15
temperature = 0.5
for epoch in range(num_epochs):
    total_loss = 0.0
    bs=0
    for i, (images, _) in enumerate(train_loader):
        images = images.to(device)

        # Forward pass
        images_aug1 = augment(images).to(device)
        images_aug2 = augment(images).to(device)

        features1 = projection_head((resnet_model(images_aug1),), device=device)
        features2 = projection_head((resnet_model(images_aug2),), device=device)

        # Calculate loss
        loss = NTXentLoss(features1, features2, temperature)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        print(f"batch [{bs}],Epoch going [{epoch}], Loss: {total_loss}")
        bs+=1
    # Print epoch loss
    print(f"epoch[{epoch+1}/{num_epochs}], Loss: {total_loss / len(train_loader):.4f}")
   
    #model checkpoint
    checkpoint_path = 'resnet_simclr_x-ray_checkpoint.pth'

    # Save the model checkpoint
    torch.save({
    'epoch': epoch,
    'model_state_dict': resnet_model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'loss': total_loss / len(train_loader),
    }, checkpoint_path)

# %%
checkpoint = torch.load('resnet_simclr_checkpoint.pth')
model_state_dict = checkpoint['model_state_dict']

# %%
resnet_model = models.resnet18(pretrained=False)  # Adjust model type if different
resnet_model.fc = nn.Identity()

# Load the model state
resnet_model.load_state_dict(model_state_dict)

# Ensure the model is on the correct device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
resnet_model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Identity()
# )

# %%
print("Final layer:", resnet_model.fc)
# Out:
# Final layer: Identity()

# %%
# Ensure the model is in eval mode if not training (important for BatchNorm and Dropout layers)
resnet_model.eval()

# Forward pass through the model up to the average pooling layer
# This approach utilizes the model's inherent structure, ensuring correct layer application
# Out:
# Output size: torch.Size([1, 512, 1, 1])
# Output size: torch.Size([1, 512, 1, 1])
# Features shape just before the final layer: torch.Size([1, 512])

# %%
# Initialize parameters for the linear layer
num_features = 512  # This is typical for ResNet-18's final layer output
num_classes = 10
linear_layer = nn.Linear(num_features, num_classes).to(device)

criterion = nn.CrossEntropyLoss()
# Optimizer for the linear layer
optimizer = torch.optim.Adam(linear_layer.parameters(), lr=0.001)

# %%
transform = transforms.Compose([
    transforms.ToTensor()  # Converts image to Tensor and scales pixels between 0 and 1
])

# %%
from torchvision import datasets, transforms

train_dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4)

# %%
def setup_model(original_model, num_features, num_classes, device):
    # Set the original fully connected layer to Identity, disabling it
    
    # Create a new classifier layer
    classifier = nn.Linear(num_features, num_classes).to(device)
    
    return original_model, classifier

num_features = 512  # Output size from the last pooling layer of ResNet
num_classes = 10    # Define the number of classes for your task
resnet_model, classifier = setup_model(resnet_model, num_features, num_classes, device)

# %%
def forward_pass(images, feature_extractor, classifier):
    # Forward through feature extractor
    features = feature_extractor(images)
    
    # Forward through classifier
    outputs = classifier(features)
    
    return outputs

# %%
import torch.optim as optim

# Setup optimizer for the classifier only
optimizer = optim.Adam(classifier.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

num_epochs = 15
for epoch in range(num_epochs):
    running_loss = 0.0
    correct = 0
    total = 0
    
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        # Assuming resizing and channel replication if necessary
        images = torch.nn.functional.interpolate(images, size=(32, 32))
        images = images.repeat(1, 3, 1, 1)

        # Compute outputs
        outputs = forward_pass(images, resnet_model, classifier)
        
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        print(f'Epoch Going {epoch+1}: Loss = {running_loss:.4f}, Accuracy = {100 * (correct / total)}%')
        
    epoch_loss = running_loss / len(train_loader)
    epoch_accuracy = 100 * correct / total
    print(f'Epoch {epoch+1}: Loss = {epoch_loss:.4f}, Accuracy = {epoch_accuracy:.2f}%')
# Out:
# Epoch Going 1: Loss = 1.2339, Accuracy = 59.375%
# Epoch Going 1: Loss = 2.1694, Accuracy = 64.84375%
# Epoch Going 1: Loss = 3.1997, Accuracy = 64.0625%
# Epoch Going 1: Loss = 4.3987, Accuracy = 63.671875%
# Epoch Going 1: Loss = 5.6626, Accuracy = 61.25000000000001%
# Epoch Going 1: Loss = 7.0170, Accuracy = 60.416666666666664%
# Epoch Going 1: Loss = 7.9288, Accuracy = 61.16071428571429%
# Epoch Going 1: Loss = 8.9152, Accuracy = 61.9140625%
# Epoch Going 1: Loss = 9.9543, Accuracy = 61.458333333333336%
# Epoch Going 1: Loss = 11.1449, Accuracy = 61.71875%
# Epoch Going 1: Loss = 12.1161, Accuracy = 61.93181818181818%
# Epoch Going 1: Loss = 13.1333, Accuracy = 61.71875%
# Epoch Going 1: Loss = 14.1060, Accuracy = 62.25961538461539%
# Epoch Going 1: Loss = 15.0588, Accuracy = 62.38839285714286%
# Epoch Going 1: Loss = 16.2242, Accuracy = 61.979166666666664%
# Epoch Going 1: Loss = 17.2858, Accuracy = 62.3046875%
# Epoch Going 1: Loss = 18.2051, Accuracy = 62.5%
# Epoch Going 1: Loss = 18.9797, Accuracy = 63.19444444444444%
# Epoch Going 1: Loss = 19.8136, Accuracy = 63.56907894736842%
# Epoch Going 1: Loss = 21.1308, Accuracy = 63.20312500000001%
# Epoch Going 1: Loss = 22.1788, Accuracy = 63.24404761904761%
# Epoch Going 1: Loss = 23.1553, Accuracy = 63.63636363636363%
# Epoch Going 1: Loss = 24.2236, Accuracy = 63.58695652173913%
# Epoch Going 1: Loss = 25.1307, Accuracy = 63.802083333333336%
# Epoch Going 1: Loss = 26.1777, Accuracy = 64.0%
# Epoch Going 1: Loss = 27.1256, Accuracy = 64.30288461538461%
# Epoch Going 1: Loss = 28.3890, Accuracy = 64.00462962962963%
# Epoch Going 1: Loss = 29.4961, Accuracy = 63.72767857142857%
# Epoch Going 1: Loss = 30.3923, Accuracy = 63.73922413793104%
# Epoch Going 1: Loss = 31.2777, Accuracy = 64.21875%
# Epoch Going 1: Loss = 32.1597, Accuracy = 64.51612903225806%
# Epoch Going 1: Loss = 33.4185, Accuracy = 64.16015625%
# Epoch Going 1: Loss = 34.2636, Accuracy = 64.29924242424242%
# Epoch Going 1: Loss = 35.5462, Accuracy = 64.0625%
# Epoch Going 1: Loss = 36.4175, Accuracy = 64.19642857142858%
# Epoch Going 1: Loss = 37.3337, Accuracy = 64.23611111111111%
# Epoch Going 1: Loss = 38.4003, Accuracy = 64.1891891891892%
# Epoch Going 1: Loss = 39.4150, Accuracy = 64.1858552631579%
# Epoch Going 1: Loss = 40.4565, Accuracy = 63.90224358974359%
# Epoch Going 1: Loss = 41.5026, Accuracy = 63.828125%
# Epoch Going 1: Loss = 42.5933, Accuracy = 63.795731707317074%
# Epoch Going 1: Loss = 43.6353, Accuracy = 63.69047619047619%
# Epoch Going 1: Loss = 44.8308, Accuracy = 63.51744186046512%
# Epoch Going 1: Loss = 46.0988, Accuracy = 63.24573863636363%
# Epoch Going 1: Loss = 47.2127, Accuracy = 63.125%
# Epoch Going 1: Loss = 48.1551, Accuracy = 63.11141304347826%
# Epoch Going 1: Loss = 49.2167, Accuracy = 62.965425531914896%
# Epoch Going 1: Loss = 50.1204, Accuracy = 63.0859375%
# Epoch Going 1: Loss = 51.0814, Accuracy = 63.10586734693877%
# Epoch Going 1: Loss = 52.2016, Accuracy = 63.0625%
# Epoch Going 1: Loss = 53.6080, Accuracy = 62.8982843137255%
# Epoch Going 1: Loss = 54.6369, Accuracy = 62.770432692307686%
# Epoch Going 1: Loss = 55.5626, Accuracy = 62.9127358490566%
# Epoch Going 1: Loss = 56.6214, Accuracy = 62.96296296296296%
# Epoch Going 1: Loss = 57.5476, Accuracy = 63.03977272727273%
# Epoch Going 1: Loss = 58.5616, Accuracy = 62.97433035714286%
# Epoch Going 1: Loss = 59.4754, Accuracy = 63.04824561403509%
# Epoch Going 1: Loss = 60.5533, Accuracy = 62.984913793103445%
# Epoch Going 1: Loss = 61.6160, Accuracy = 62.89724576271186%
# Epoch Going 1: Loss = 63.0575, Accuracy = 62.78645833333333%
# Epoch Going 1: Loss = 64.3716, Accuracy = 62.5%
# Epoch Going 1: Loss = 65.2638, Accuracy = 62.525201612903224%
# Epoch Going 1: Loss = 66.2425, Accuracy = 62.648809523809526%
# Epoch Going 1: Loss = 67.3144, Accuracy = 62.6708984375%
# Epoch Going 1: Loss = 68.3939, Accuracy = 62.59615384615385%
# Epoch Going 1: Loss = 69.4025, Accuracy = 62.71306818181818%
# Epoch Going 1: Loss = 70.5761, Accuracy = 62.663246268656714%
# Epoch Going 1: Loss = 71.6274, Accuracy = 62.56893382352941%
# Epoch Going 1: Loss = 72.6585, Accuracy = 62.658514492753625%
# Epoch Going 1: Loss = 73.7613, Accuracy = 62.65625%
# Epoch Going 1: Loss = 74.8028, Accuracy = 62.65404929577465%
# Epoch Going 1: Loss = 75.9005, Accuracy = 62.717013888888886%
# Epoch Going 1: Loss = 76.9988, Accuracy = 62.714041095890416%
# Epoch Going 1: Loss = 77.7960, Accuracy = 62.83783783783784%
# Epoch Going 1: Loss = 78.9027, Accuracy = 62.854166666666664%
# Epoch Going 1: Loss = 79.8078, Accuracy = 62.911184210526315%
# Epoch Going 1: Loss = 80.8357, Accuracy = 62.94642857142857%
# Epoch Going 1: Loss = 81.7879, Accuracy = 62.980769230769226%
# Epoch Going 1: Loss = 82.8071, Accuracy = 62.9746835443038%
# Epoch Going 1: Loss = 83.7977, Accuracy = 62.96874999999999%
# Epoch Going 1: Loss = 85.1303, Accuracy = 62.86651234567901%
# Epoch Going 1: Loss = 86.4574, Accuracy = 62.70960365853659%
# Epoch Going 1: Loss = 87.6017, Accuracy = 62.61295180722891%
# Epoch Going 1: Loss = 88.6939, Accuracy = 62.593005952380956%
# Epoch Going 1: Loss = 89.7654, Accuracy = 62.61029411764706%
# Epoch Going 1: Loss = 90.9363, Accuracy = 62.46366279069767%
# Epoch Going 1: Loss = 91.9543, Accuracy = 62.42816091954023%
# Epoch Going 1: Loss = 92.9209, Accuracy = 62.57102272727273%
# Epoch Going 1: Loss = 93.8909, Accuracy = 62.62289325842697%
# Epoch Going 1: Loss = 94.9048, Accuracy = 62.60416666666667%
# Epoch Going 1: Loss = 96.1782, Accuracy = 62.5%
# Epoch Going 1: Loss = 97.3237, Accuracy = 62.5%
# Epoch Going 1: Loss = 98.3290, Accuracy = 62.46639784946236%
# Epoch Going 1: Loss = 99.4282, Accuracy = 62.516622340425535%
# Epoch Going 1: Loss = 100.6029, Accuracy = 62.434210526315795%
# Epoch Going 1: Loss = 101.6087, Accuracy = 62.434895833333336%
# Epoch Going 1: Loss = 102.8006, Accuracy = 62.371134020618555%
# Epoch Going 1: Loss = 104.0020, Accuracy = 62.308673469387756%
# Epoch Going 1: Loss = 104.7222, Accuracy = 62.5%
# Epoch Going 1: Loss = 105.6580, Accuracy = 62.53125000000001%
# Epoch Going 1: Loss = 106.9251, Accuracy = 62.4690594059406%
# Epoch Going 1: Loss = 107.8580, Accuracy = 62.53063725490197%
# Epoch Going 1: Loss = 108.8385, Accuracy = 62.59101941747572%
# Epoch Going 1: Loss = 109.9442, Accuracy = 62.575120192307686%
# Epoch Going 1: Loss = 110.7191, Accuracy = 62.708333333333336%
# Epoch Going 1: Loss = 112.1412, Accuracy = 62.603183962264154%
# Epoch Going 1: Loss = 113.3205, Accuracy = 62.529205607476634%
# Epoch Going 1: Loss = 114.2280, Accuracy = 62.60127314814815%
# Epoch Going 1: Loss = 115.1678, Accuracy = 62.61467889908256%
# Epoch Going 1: Loss = 116.1325, Accuracy = 62.59943181818181%
# Epoch Going 1: Loss = 117.1484, Accuracy = 62.59853603603604%
# Epoch Going 1: Loss = 118.1286, Accuracy = 62.63950892857143%
# Epoch Going 1: Loss = 119.3204, Accuracy = 62.58296460176991%
# Epoch Going 1: Loss = 120.3617, Accuracy = 62.595942982456144%
# Epoch Going 1: Loss = 121.4395, Accuracy = 62.60869565217392%
# Epoch Going 1: Loss = 122.5574, Accuracy = 62.594288793103445%
# Epoch Going 1: Loss = 123.5650, Accuracy = 62.5534188034188%
# Epoch Going 1: Loss = 124.6200, Accuracy = 62.52648305084746%
# Epoch Going 1: Loss = 125.5551, Accuracy = 62.60504201680672%
# Epoch Going 1: Loss = 126.6562, Accuracy = 62.61718750000001%
# Epoch Going 1: Loss = 127.9015, Accuracy = 62.603305785123965%
# Epoch Going 1: Loss = 128.9412, Accuracy = 62.60245901639344%
# Epoch Going 1: Loss = 129.9469, Accuracy = 62.58892276422764%
# Epoch Going 1: Loss = 130.9193, Accuracy = 62.65120967741935%
# Epoch Going 1: Loss = 132.2754, Accuracy = 62.5375%
# Epoch Going 1: Loss = 133.2818, Accuracy = 62.51240079365079%
# Epoch Going 1: Loss = 134.3924, Accuracy = 62.487696850393704%
# Epoch Going 1: Loss = 135.4749, Accuracy = 62.451171875%
# Epoch Going 1: Loss = 136.5418, Accuracy = 62.41521317829457%
# Epoch Going 1: Loss = 137.5151, Accuracy = 62.45192307692308%
# Epoch Going 1: Loss = 138.6445, Accuracy = 62.42843511450382%
# Epoch Going 1: Loss = 139.8469, Accuracy = 62.3342803030303%
# Epoch Going 1: Loss = 140.8015, Accuracy = 62.38251879699248%
# Epoch Going 1: Loss = 141.8388, Accuracy = 62.34841417910447%
# Epoch Going 1: Loss = 143.2022, Accuracy = 62.2337962962963%
# Epoch Going 1: Loss = 144.1528, Accuracy = 62.23575367647059%
# Epoch Going 1: Loss = 145.1598, Accuracy = 62.27189781021898%
# Epoch Going 1: Loss = 146.0929, Accuracy = 62.30751811594203%
# Epoch Going 1: Loss = 147.1963, Accuracy = 62.30890287769785%
# Epoch Going 1: Loss = 148.2947, Accuracy = 62.254464285714285%
# Epoch Going 1: Loss = 149.2293, Accuracy = 62.27836879432624%
# Epoch Going 1: Loss = 150.2060, Accuracy = 62.279929577464785%
# Epoch Going 1: Loss = 151.1797, Accuracy = 62.35795454545454%
# Epoch Going 1: Loss = 152.1086, Accuracy = 62.380642361111114%
# Epoch Going 1: Loss = 153.3569, Accuracy = 62.35991379310345%
# Epoch Going 1: Loss = 154.3579, Accuracy = 62.36087328767124%
# Epoch Going 1: Loss = 155.2641, Accuracy = 62.40433673469388%
# Epoch Going 1: Loss = 156.4057, Accuracy = 62.352195945945944%
# Epoch Going 1: Loss = 157.5139, Accuracy = 62.38464765100671%
# Epoch Going 1: Loss = 158.7147, Accuracy = 62.39583333333333%
# Epoch Going 1: Loss = 159.7919, Accuracy = 62.37582781456954%
# Epoch Going 1: Loss = 160.8241, Accuracy = 62.35608552631579%
# Epoch Going 1: Loss = 161.5370, Accuracy = 62.428513071895416%
# Epoch Going 1: Loss = 162.8583, Accuracy = 62.33766233766234%
# Epoch Going 1: Loss = 163.8138, Accuracy = 62.3991935483871%
# Epoch Going 1: Loss = 164.7410, Accuracy = 62.43990384615385%
# Epoch Going 1: Loss = 165.8491, Accuracy = 62.42038216560509%
# Epoch Going 1: Loss = 166.9157, Accuracy = 62.39121835443038%
# Epoch Going 1: Loss = 167.7645, Accuracy = 62.41155660377359%
# Epoch Going 1: Loss = 168.7857, Accuracy = 62.44140625%
# Epoch Going 1: Loss = 169.8191, Accuracy = 62.480590062111794%
# Epoch Going 1: Loss = 170.9087, Accuracy = 62.48070987654321%
# Epoch Going 1: Loss = 171.8203, Accuracy = 62.50958588957055%
# Epoch Going 1: Loss = 172.8664, Accuracy = 62.490472560975604%
# Epoch Going 1: Loss = 173.7253, Accuracy = 62.5189393939394%
# Epoch Going 1: Loss = 174.6504, Accuracy = 62.55647590361446%
# Epoch Going 1: Loss = 175.7548, Accuracy = 62.537425149700596%
# Epoch Going 1: Loss = 176.7717, Accuracy = 62.58370535714286%
# Epoch Going 1: Loss = 177.6362, Accuracy = 62.620192307692314%
# Epoch Going 1: Loss = 178.7952, Accuracy = 62.601102941176464%
# Epoch Going 1: Loss = 180.0640, Accuracy = 62.563961988304094%
# Epoch Going 1: Loss = 181.2335, Accuracy = 62.563590116279066%
# Epoch Going 1: Loss = 182.2633, Accuracy = 62.57225433526011%
# Epoch Going 1: Loss = 183.3964, Accuracy = 62.53591954022989%
# Epoch Going 1: Loss = 184.5528, Accuracy = 62.49107142857143%
# Epoch Going 1: Loss = 185.6694, Accuracy = 62.49112215909091%
# Epoch Going 1: Loss = 186.5572, Accuracy = 62.5%
# Epoch Going 1: Loss = 187.6311, Accuracy = 62.46488764044944%
# Epoch Going 1: Loss = 188.5932, Accuracy = 62.508729050279335%
# Epoch Going 1: Loss = 189.6644, Accuracy = 62.49131944444445%
# Epoch Going 1: Loss = 190.8806, Accuracy = 62.474102209944746%
# Epoch Going 1: Loss = 192.2567, Accuracy = 62.43131868131868%
# Epoch Going 1: Loss = 193.3146, Accuracy = 62.465846994535525%
# Epoch Going 1: Loss = 194.2859, Accuracy = 62.466032608695656%
# Epoch Going 1: Loss = 195.2563, Accuracy = 62.47466216216216%
# Epoch Going 1: Loss = 196.2843, Accuracy = 62.491599462365585%
# Epoch Going 1: Loss = 197.1879, Accuracy = 62.525066844919785%
# Epoch Going 1: Loss = 198.2210, Accuracy = 62.54155585106383%
# Epoch Going 1: Loss = 199.4511, Accuracy = 62.45039682539682%
# Epoch Going 1: Loss = 200.4182, Accuracy = 62.42598684210526%
# Epoch Going 1: Loss = 201.5511, Accuracy = 62.450916230366495%
# Epoch Going 1: Loss = 202.5335, Accuracy = 62.443033854166664%
# Epoch Going 1: Loss = 203.5816, Accuracy = 62.443329015544045%
# Epoch Going 1: Loss = 204.5572, Accuracy = 62.459729381443296%
# Epoch Going 1: Loss = 205.4665, Accuracy = 62.47596153846153%
# Epoch Going 1: Loss = 206.7453, Accuracy = 62.452168367346935%
# Epoch Going 1: Loss = 207.7453, Accuracy = 62.42861675126904%
# Epoch Going 1: Loss = 208.8542, Accuracy = 62.39741161616161%
# Epoch Going 1: Loss = 209.9067, Accuracy = 62.4214824120603%
# Epoch Going 1: Loss = 211.1049, Accuracy = 62.4140625%
# Epoch Going 1: Loss = 211.9450, Accuracy = 62.46890547263681%
# Epoch Going 1: Loss = 212.6625, Accuracy = 62.561881188118804%
# Epoch Going 1: Loss = 213.9350, Accuracy = 62.507697044334975%
# Epoch Going 1: Loss = 215.0389, Accuracy = 62.5%
# Epoch Going 1: Loss = 216.1929, Accuracy = 62.46951219512196%
# Epoch Going 1: Loss = 217.2325, Accuracy = 62.446905339805824%
# Epoch Going 1: Loss = 218.3867, Accuracy = 62.43206521739131%
# Epoch Going 1: Loss = 219.3384, Accuracy = 62.41736778846154%
# Epoch Going 1: Loss = 220.2391, Accuracy = 62.477571770334926%
# Epoch Going 1: Loss = 221.2964, Accuracy = 62.5%
# Epoch Going 1: Loss = 222.4656, Accuracy = 62.47778436018957%
# Epoch Going 1: Loss = 223.5700, Accuracy = 62.47051886792453%
# Epoch Going 1: Loss = 224.6326, Accuracy = 62.45598591549296%
# Epoch Going 1: Loss = 225.6138, Accuracy = 62.470794392523366%
# Epoch Going 1: Loss = 226.5458, Accuracy = 62.51453488372093%
# Epoch Going 1: Loss = 227.3862, Accuracy = 62.565104166666664%
# Epoch Going 1: Loss = 228.5011, Accuracy = 62.56480414746544%
# Epoch Going 1: Loss = 229.4001, Accuracy = 62.58600917431193%
# Epoch Going 1: Loss = 230.5259, Accuracy = 62.59275114155252%
# Epoch Going 1: Loss = 231.5242, Accuracy = 62.59232954545455%
# Epoch Going 1: Loss = 232.7249, Accuracy = 62.54242081447964%
# Epoch Going 1: Loss = 233.9006, Accuracy = 62.507038288288285%
# Epoch Going 1: Loss = 234.8526, Accuracy = 62.5560538116592%
# Epoch Going 1: Loss = 235.8046, Accuracy = 62.59068080357143%
# Epoch Going 1: Loss = 237.0633, Accuracy = 62.54861111111111%
# Epoch Going 1: Loss = 238.0503, Accuracy = 62.569137168141594%
# Epoch Going 1: Loss = 238.9763, Accuracy = 62.575715859030836%
# Epoch Going 1: Loss = 240.2394, Accuracy = 62.54797149122807%
# Epoch Going 1: Loss = 241.1919, Accuracy = 62.55458515283843%
# Epoch Going 1: Loss = 242.3798, Accuracy = 62.547554347826086%
# Epoch Going 1: Loss = 243.4350, Accuracy = 62.54058441558441%
# Epoch Going 1: Loss = 244.5478, Accuracy = 62.513469827586206%
# Epoch Going 1: Loss = 245.5237, Accuracy = 62.54694206008584%
# Epoch Going 1: Loss = 246.7323, Accuracy = 62.526709401709404%
# Epoch Going 1: Loss = 247.6264, Accuracy = 62.55984042553191%
# Epoch Going 1: Loss = 248.7133, Accuracy = 62.52648305084746%
# Epoch Going 1: Loss = 249.6248, Accuracy = 62.546149789029535%
# Epoch Going 1: Loss = 250.5527, Accuracy = 62.565651260504204%
# Epoch Going 1: Loss = 251.9318, Accuracy = 62.54576359832637%
# Epoch Going 1: Loss = 252.8515, Accuracy = 62.55859375%
# Epoch Going 1: Loss = 253.9018, Accuracy = 62.5713174273859%
# Epoch Going 1: Loss = 254.7650, Accuracy = 62.56456611570248%
# Epoch Going 1: Loss = 255.8673, Accuracy = 62.57716049382716%
# Epoch Going 1: Loss = 256.8894, Accuracy = 62.557633196721305%
# Epoch Going 1: Loss = 257.9747, Accuracy = 62.55739795918367%
# Epoch Going 1: Loss = 259.0149, Accuracy = 62.54446138211382%
# Epoch Going 1: Loss = 260.1018, Accuracy = 62.5253036437247%
# Epoch Going 1: Loss = 261.2463, Accuracy = 62.51890120967742%
# Epoch Going 1: Loss = 262.4239, Accuracy = 62.49372489959839%
# Epoch Going 1: Loss = 263.8111, Accuracy = 62.425%
# Epoch Going 1: Loss = 264.8948, Accuracy = 62.45642430278885%
# Epoch Going 1: Loss = 265.8651, Accuracy = 62.45659722222222%
# Epoch Going 1: Loss = 267.0991, Accuracy = 62.42588932806324%
# Epoch Going 1: Loss = 268.2111, Accuracy = 62.39542322834646%
# Epoch Going 1: Loss = 269.1919, Accuracy = 62.4264705882353%
# Epoch Going 1: Loss = 270.4560, Accuracy = 62.4267578125%
# Epoch Going 1: Loss = 271.3154, Accuracy = 62.47568093385214%
# Epoch Going 1: Loss = 272.4001, Accuracy = 62.48183139534884%
# Epoch Going 1: Loss = 273.5231, Accuracy = 62.5%
# Epoch Going 1: Loss = 274.6061, Accuracy = 62.48798076923077%
# Epoch Going 1: Loss = 275.5482, Accuracy = 62.50598659003831%
# Epoch Going 1: Loss = 276.5652, Accuracy = 62.51789122137404%
# Epoch Going 1: Loss = 277.4418, Accuracy = 62.553469581749056%
# Epoch Going 1: Loss = 278.2326, Accuracy = 62.58877840909091%
# Epoch Going 1: Loss = 279.2498, Accuracy = 62.61202830188679%
# Epoch Going 1: Loss = 280.1537, Accuracy = 62.640977443609025%
# Epoch Going 1: Loss = 281.0514, Accuracy = 62.65800561797753%
# Epoch Going 1: Loss = 282.0566, Accuracy = 62.663246268656714%
# Epoch Going 1: Loss = 283.1640, Accuracy = 62.67425650557621%
# Epoch Going 1: Loss = 284.0216, Accuracy = 62.69097222222222%
# Epoch Going 1: Loss = 284.8595, Accuracy = 62.71909594095941%
# Epoch Going 1: Loss = 285.9612, Accuracy = 62.6953125%
# Epoch Going 1: Loss = 286.8369, Accuracy = 62.7117673992674%
# Epoch Going 1: Loss = 288.1148, Accuracy = 62.659671532846716%
# Epoch Going 1: Loss = 289.1106, Accuracy = 62.67045454545455%
# Epoch Going 1: Loss = 290.2224, Accuracy = 62.66417572463768%
# Epoch Going 1: Loss = 291.1625, Accuracy = 62.657942238267154%
# Epoch Going 1: Loss = 292.2330, Accuracy = 62.66861510791367%
# Epoch Going 1: Loss = 293.4990, Accuracy = 62.64000896057348%
# Epoch Going 1: Loss = 294.5027, Accuracy = 62.661830357142854%
# Epoch Going 1: Loss = 295.6528, Accuracy = 62.66125444839857%
# Epoch Going 1: Loss = 296.6959, Accuracy = 62.66622340425532%
# Epoch Going 1: Loss = 297.5399, Accuracy = 62.693242049469966%
# Epoch Going 1: Loss = 298.5956, Accuracy = 62.70906690140845%
# Epoch Going 1: Loss = 299.4653, Accuracy = 62.71929824561403%
# Epoch Going 1: Loss = 300.4548, Accuracy = 62.74038461538461%
# Epoch Going 1: Loss = 301.4011, Accuracy = 62.75043554006968%
# Epoch Going 1: Loss = 302.4561, Accuracy = 62.73871527777778%
# Epoch Going 1: Loss = 303.4105, Accuracy = 62.73788927335641%
# Epoch Going 1: Loss = 304.4780, Accuracy = 62.74245689655172%
# Epoch Going 1: Loss = 305.3382, Accuracy = 62.779209621993125%
# Epoch Going 1: Loss = 306.6873, Accuracy = 62.73544520547946%
# Epoch Going 1: Loss = 307.8111, Accuracy = 62.73997440273038%
# Epoch Going 1: Loss = 309.0449, Accuracy = 62.73384353741497%
# Epoch Going 1: Loss = 310.1053, Accuracy = 62.748940677966104%
# Epoch Going 1: Loss = 311.0598, Accuracy = 62.763935810810814%
# Epoch Going 1: Loss = 312.2905, Accuracy = 62.72095959595959%
# Epoch Going 1: Loss = 313.3913, Accuracy = 62.72021812080537%
# Epoch Going 1: Loss = 314.2156, Accuracy = 62.74561036789298%
# Epoch Going 1: Loss = 315.5175, Accuracy = 62.713541666666664%
# Epoch Going 1: Loss = 316.3440, Accuracy = 62.733596345514954%
# Epoch Going 1: Loss = 317.4026, Accuracy = 62.71730132450332%
# Epoch Going 1: Loss = 318.3641, Accuracy = 62.73205445544554%
# Epoch Going 1: Loss = 319.3391, Accuracy = 62.74157072368421%
# Epoch Going 1: Loss = 320.4401, Accuracy = 62.72540983606557%
# Epoch Going 1: Loss = 321.6486, Accuracy = 62.688929738562095%
# Epoch Going 1: Loss = 322.5244, Accuracy = 62.70867263843648%
# Epoch Going 1: Loss = 323.6099, Accuracy = 62.70799512987013%
# Epoch Going 1: Loss = 324.5252, Accuracy = 62.7174352750809%
# Epoch Going 1: Loss = 325.5167, Accuracy = 62.721774193548384%
# Epoch Going 1: Loss = 326.6402, Accuracy = 62.70096463022507%
# Epoch Going 1: Loss = 327.6084, Accuracy = 62.69030448717948%
# Epoch Going 1: Loss = 328.5915, Accuracy = 62.69968051118211%
# Epoch Going 1: Loss = 329.6473, Accuracy = 62.679140127388536%
# Epoch Going 1: Loss = 330.6094, Accuracy = 62.67857142857143%
# Epoch Going 1: Loss = 331.9547, Accuracy = 62.62856012658228%
# Epoch Going 1: Loss = 332.9172, Accuracy = 62.6577287066246%
# Epoch Going 1: Loss = 333.8135, Accuracy = 62.676886792452834%
# Epoch Going 1: Loss = 334.7595, Accuracy = 62.7057210031348%
# Epoch Going 1: Loss = 335.6553, Accuracy = 62.71484375000001%
# Epoch Going 1: Loss = 336.8340, Accuracy = 62.69470404984424%
# Epoch Going 1: Loss = 338.0964, Accuracy = 62.67468944099379%
# Epoch Going 1: Loss = 339.2803, Accuracy = 62.66931114551083%
# Epoch Going 1: Loss = 340.2159, Accuracy = 62.68807870370371%
# Epoch Going 1: Loss = 341.3219, Accuracy = 62.69711538461539%
# Epoch Going 1: Loss = 342.5471, Accuracy = 62.66775306748467%
# Epoch Going 1: Loss = 343.4939, Accuracy = 62.667240061162076%
# Epoch Going 1: Loss = 344.3454, Accuracy = 62.685785060975604%
# Epoch Going 1: Loss = 345.3221, Accuracy = 62.68996960486323%
# Epoch Going 1: Loss = 346.2660, Accuracy = 62.70359848484849%
# Epoch Going 1: Loss = 347.3601, Accuracy = 62.721865558912384%
# Epoch Going 1: Loss = 348.4936, Accuracy = 62.70707831325302%
# Epoch Going 1: Loss = 349.7651, Accuracy = 62.664226726726724%
# Epoch Going 1: Loss = 350.6905, Accuracy = 62.68244760479041%
# Epoch Going 1: Loss = 351.6704, Accuracy = 62.70522388059702%
# Epoch Going 1: Loss = 352.9779, Accuracy = 62.699962797619044%
# Epoch Going 1: Loss = 354.0399, Accuracy = 62.7040059347181%
# Epoch Going 1: Loss = 355.1219, Accuracy = 62.69415680473372%
# Epoch Going 1: Loss = 356.0929, Accuracy = 62.688974926253685%
# Epoch Going 1: Loss = 357.2575, Accuracy = 62.67922794117647%
# Epoch Going 1: Loss = 358.5190, Accuracy = 62.646627565982406%
# Epoch Going 1: Loss = 359.4307, Accuracy = 62.669042397660824%
# Epoch Going 1: Loss = 360.5387, Accuracy = 62.68221574344023%
# Epoch Going 1: Loss = 361.5927, Accuracy = 62.686228197674424%
# Epoch Going 1: Loss = 362.6424, Accuracy = 62.68115942028986%
# Epoch Going 1: Loss = 363.6548, Accuracy = 62.68515173410405%
# Epoch Going 1: Loss = 364.7787, Accuracy = 62.680115273775215%
# Epoch Going 1: Loss = 365.8272, Accuracy = 62.6885775862069%
# Epoch Going 1: Loss = 366.7120, Accuracy = 62.696991404011456%
# Epoch Going 1: Loss = 367.8828, Accuracy = 62.67410714285714%
# Epoch Going 1: Loss = 368.9829, Accuracy = 62.65135327635327%
# Epoch Going 1: Loss = 369.9147, Accuracy = 62.646484375%
# Epoch Going 1: Loss = 370.9950, Accuracy = 62.64164305949008%
# Epoch Going 1: Loss = 371.9275, Accuracy = 62.6368290960452%
# Epoch Going 1: Loss = 372.7285, Accuracy = 62.680457746478865%
# Epoch Going 1: Loss = 373.6271, Accuracy = 62.67117275280899%
# Epoch Going 1: Loss = 374.5549, Accuracy = 62.68820028011205%
# Epoch Going 1: Loss = 375.7758, Accuracy = 62.6614874301676%
# Epoch Going 1: Loss = 376.6702, Accuracy = 62.67844707520891%
# Epoch Going 1: Loss = 377.6999, Accuracy = 62.65625%
# Epoch Going 1: Loss = 378.5540, Accuracy = 62.67313019390581%
# Epoch Going 1: Loss = 379.3159, Accuracy = 62.71581491712708%
# Epoch Going 1: Loss = 380.2490, Accuracy = 62.74104683195593%
# Epoch Going 1: Loss = 381.3797, Accuracy = 62.72750686813187%
# Epoch Going 1: Loss = 382.4051, Accuracy = 62.73544520547946%
# Epoch Going 1: Loss = 383.3542, Accuracy = 62.747609289617486%
# Epoch Going 1: Loss = 384.4408, Accuracy = 62.74693460490464%
# Epoch Going 1: Loss = 385.4585, Accuracy = 62.76324728260869%
# Epoch Going 1: Loss = 386.5049, Accuracy = 62.74983062330624%
# Epoch Going 1: Loss = 387.6052, Accuracy = 62.736486486486484%
# Epoch Going 1: Loss = 388.3863, Accuracy = 62.75690700808625%
# Epoch Going 1: Loss = 389.2534, Accuracy = 62.77721774193549%
# Epoch Going 1: Loss = 390.2267, Accuracy = 62.776474530831095%
# Epoch Going 1: Loss = 391.2209, Accuracy = 62.77991310160428%
# Epoch Going 1: Loss = 392.3651, Accuracy = 62.787499999999994%
# Epoch Going 1: Loss = 393.4136, Accuracy = 62.77842420212766%
# Epoch Going 1: Loss = 394.4774, Accuracy = 62.78183023872679%
# Epoch Going 1: Loss = 395.6693, Accuracy = 62.764550264550266%
# Epoch Going 1: Loss = 396.6594, Accuracy = 62.77622031662269%
# Epoch Going 1: Loss = 397.5823, Accuracy = 62.796052631578945%
# Epoch Going 1: Loss = 398.6314, Accuracy = 62.79117454068241%
# Epoch Going 1: Loss = 399.8316, Accuracy = 62.769960732984295%
# Epoch Going 1: Loss = 400.9002, Accuracy = 62.76109660574413%
# Epoch Going 1: Loss = 401.8885, Accuracy = 62.760416666666664%
# Epoch Going 1: Loss = 402.8877, Accuracy = 62.75974025974026%
# Epoch Going 1: Loss = 404.0267, Accuracy = 62.738827720207254%
# Epoch Going 1: Loss = 405.2569, Accuracy = 62.71802325581395%
# Epoch Going 1: Loss = 406.3720, Accuracy = 62.70940721649485%
# Epoch Going 1: Loss = 407.3202, Accuracy = 62.71690231362468%
# Epoch Going 1: Loss = 408.2348, Accuracy = 62.72035256410257%
# Epoch Going 1: Loss = 409.2187, Accuracy = 62.73177749360613%
# Epoch Going 1: Loss = 410.2345, Accuracy = 62.72720025510205%
# Epoch Going 1: Loss = 410.9846, Accuracy = 62.73854961832062%
# Epoch Going 1: Loss = 411.9642, Accuracy = 62.765704314720814%
# Epoch Going 1: Loss = 412.9743, Accuracy = 62.77689873417721%
# Epoch Going 1: Loss = 413.9619, Accuracy = 62.760416666666664%
# Epoch Going 1: Loss = 414.9253, Accuracy = 62.77156801007556%
# Epoch Going 1: Loss = 416.1264, Accuracy = 62.76695979899497%
# Epoch Going 1: Loss = 417.3006, Accuracy = 62.750626566416045%
# Epoch Going 1: Loss = 418.3027, Accuracy = 62.73828125000001%
# Epoch Going 1: Loss = 419.5092, Accuracy = 62.72599750623441%
# Epoch Going 1: Loss = 420.5031, Accuracy = 62.71377487562189%
# Epoch Going 1: Loss = 421.4488, Accuracy = 62.70936724565757%
# Epoch Going 1: Loss = 422.5867, Accuracy = 62.70884900990099%
# Epoch Going 1: Loss = 423.5394, Accuracy = 62.719907407407405%
# Epoch Going 1: Loss = 424.5105, Accuracy = 62.71551724137932%
# Epoch Going 1: Loss = 425.6179, Accuracy = 62.71114864864865%
# Epoch Going 1: Loss = 426.6675, Accuracy = 62.71446078431373%
# Epoch Going 1: Loss = 427.8520, Accuracy = 62.694834963325185%
# Epoch Going 1: Loss = 428.9175, Accuracy = 62.70198170731708%
# Epoch Going 1: Loss = 429.9200, Accuracy = 62.693886861313864%
# Epoch Going 1: Loss = 430.8346, Accuracy = 62.708586165048544%
# Epoch Going 1: Loss = 431.8789, Accuracy = 62.70808111380145%
# Epoch Going 1: Loss = 433.0362, Accuracy = 62.711352657004824%
# Epoch Going 1: Loss = 434.0323, Accuracy = 62.70707831325302%
# Epoch Going 1: Loss = 435.1437, Accuracy = 62.702824519230774%
# Epoch Going 1: Loss = 436.3138, Accuracy = 62.67985611510791%
# Epoch Going 1: Loss = 437.3668, Accuracy = 62.6869019138756%
# Epoch Going 1: Loss = 438.3718, Accuracy = 62.686455847255374%
# Epoch Going 1: Loss = 439.4252, Accuracy = 62.69717261904761%
# Epoch Going 1: Loss = 440.5495, Accuracy = 62.68557007125891%
# Epoch Going 1: Loss = 441.5503, Accuracy = 62.68883293838863%
# Epoch Going 1: Loss = 442.7062, Accuracy = 62.673611111111114%
# Epoch Going 1: Loss = 443.5795, Accuracy = 62.68794221698113%
# Epoch Going 1: Loss = 444.5130, Accuracy = 62.6985294117647%
# Epoch Going 1: Loss = 445.4085, Accuracy = 62.720070422535215%
# Epoch Going 1: Loss = 446.7422, Accuracy = 62.69759953161592%
# Epoch Going 1: Loss = 447.8077, Accuracy = 62.70443925233645%
# Epoch Going 1: Loss = 448.9965, Accuracy = 62.7039627039627%
# Epoch Going 1: Loss = 450.0193, Accuracy = 62.68531976744186%
# Epoch Going 1: Loss = 450.9920, Accuracy = 62.688515081206496%
# Epoch Going 1: Loss = 451.9758, Accuracy = 62.68446180555556%
# Epoch Going 1: Loss = 452.8541, Accuracy = 62.698469976905315%
# Epoch Going 1: Loss = 453.6442, Accuracy = 62.694412442396306%
# Epoch Going 1: Loss = 454.6795, Accuracy = 62.690373563218394%
# Epoch Going 1: Loss = 456.1124, Accuracy = 62.654099770642205%
# Epoch Going 1: Loss = 457.3986, Accuracy = 62.64302059496567%
# Epoch Going 1: Loss = 458.4790, Accuracy = 62.63912671232876%
# Epoch Going 1: Loss = 459.6336, Accuracy = 62.62813211845103%
# Epoch Going 1: Loss = 460.6813, Accuracy = 62.64204545454546%
# Epoch Going 1: Loss = 461.5973, Accuracy = 62.65589569160998%
# Epoch Going 1: Loss = 462.4446, Accuracy = 62.67321832579186%
# Epoch Going 1: Loss = 463.6756, Accuracy = 62.6622460496614%
# Epoch Going 1: Loss = 464.9256, Accuracy = 62.63724662162162%
# Epoch Going 1: Loss = 466.0236, Accuracy = 62.64044943820225%
# Epoch Going 1: Loss = 467.0912, Accuracy = 62.647141255605376%
# Epoch Going 1: Loss = 468.1209, Accuracy = 62.657298657718115%
# Epoch Going 1: Loss = 469.1559, Accuracy = 62.65345982142857%
# Epoch Going 1: Loss = 470.3586, Accuracy = 62.65659799554566%
# Epoch Going 1: Loss = 471.6118, Accuracy = 62.638888888888886%
# Epoch Going 1: Loss = 473.0773, Accuracy = 62.62818736141907%
# Epoch Going 1: Loss = 474.3324, Accuracy = 62.60716261061947%
# Epoch Going 1: Loss = 475.1987, Accuracy = 62.62417218543046%
# Epoch Going 1: Loss = 476.1228, Accuracy = 62.64110682819384%
# Epoch Going 1: Loss = 477.3266, Accuracy = 62.637362637362635%
# Epoch Going 1: Loss = 478.4627, Accuracy = 62.64734100877193%
# Epoch Going 1: Loss = 479.4141, Accuracy = 62.657275711159734%
# Epoch Going 1: Loss = 480.4003, Accuracy = 62.65693231441048%
# Epoch Going 1: Loss = 481.3611, Accuracy = 62.67020697167756%
# Epoch Going 1: Loss = 482.6447, Accuracy = 62.67323369565217%
# Epoch Going 1: Loss = 483.7964, Accuracy = 62.66607917570499%
# Epoch Going 1: Loss = 484.9230, Accuracy = 62.66910173160173%
# Epoch Going 1: Loss = 485.9183, Accuracy = 62.68223542116631%
# Epoch Going 1: Loss = 487.0578, Accuracy = 62.681842672413794%
# Epoch Going 1: Loss = 488.4041, Accuracy = 62.64448924731183%
# Epoch Going 1: Loss = 489.4139, Accuracy = 62.64082618025751%
# Epoch Going 1: Loss = 490.6513, Accuracy = 62.62714132762313%
# Epoch Going 1: Loss = 491.4988, Accuracy = 62.643563034188034%
# Epoch Going 1: Loss = 492.4312, Accuracy = 62.64992004264393%
# Epoch Going 1: Loss = 493.3242, Accuracy = 62.652925531914896%
# Epoch Going 1: Loss = 494.3681, Accuracy = 62.63933121019109%
# Epoch Going 1: Loss = 495.5769, Accuracy = 62.63241525423729%
# Epoch Going 1: Loss = 496.7589, Accuracy = 62.62552854122622%
# Epoch Going 1: Loss = 497.8695, Accuracy = 62.60878164556962%
# Epoch Going 1: Loss = 498.7674, Accuracy = 62.61513157894737%
# Epoch Going 1: Loss = 499.8103, Accuracy = 62.6313025210084%
# Epoch Going 1: Loss = 500.9720, Accuracy = 62.637578616352194%
# Epoch Going 1: Loss = 502.1185, Accuracy = 62.63729079497908%
# Epoch Going 1: Loss = 503.0935, Accuracy = 62.64352818371608%
# Epoch Going 1: Loss = 504.1937, Accuracy = 62.63671875%
# Epoch Going 1: Loss = 505.0452, Accuracy = 62.649428274428274%
# Epoch Going 1: Loss = 506.2088, Accuracy = 62.649118257261414%
# Epoch Going 1: Loss = 507.2698, Accuracy = 62.648809523809526%
# Epoch Going 1: Loss = 508.4228, Accuracy = 62.63558884297521%
# Epoch Going 1: Loss = 509.3859, Accuracy = 62.628865979381445%
# Epoch Going 1: Loss = 510.5928, Accuracy = 62.61574074074075%
# Epoch Going 1: Loss = 511.7199, Accuracy = 62.605877823408626%
# Epoch Going 1: Loss = 512.6593, Accuracy = 62.62487192622951%
# Epoch Going 1: Loss = 513.8188, Accuracy = 62.62461656441718%
# Epoch Going 1: Loss = 514.7243, Accuracy = 62.630739795918366%
# Epoch Going 1: Loss = 515.9693, Accuracy = 62.611379837067204%
# Epoch Going 1: Loss = 516.9364, Accuracy = 62.62068089430895%
# Epoch Going 1: Loss = 517.8631, Accuracy = 62.6394523326572%
# Epoch Going 1: Loss = 519.1512, Accuracy = 62.61386639676113%
# Epoch Going 1: Loss = 520.2979, Accuracy = 62.60416666666667%
# Epoch Going 1: Loss = 521.3027, Accuracy = 62.61655745967742%
# Epoch Going 1: Loss = 522.4087, Accuracy = 62.62575452716298%
# Epoch Going 1: Loss = 523.4222, Accuracy = 62.634914658634536%
# Epoch Going 1: Loss = 524.6418, Accuracy = 62.6377755511022%
# Epoch Going 1: Loss = 525.7358, Accuracy = 62.625%
# Epoch Going 1: Loss = 526.8401, Accuracy = 62.64034431137725%
# Epoch Going 1: Loss = 527.9813, Accuracy = 62.62761454183266%
# Epoch Going 1: Loss = 529.3030, Accuracy = 62.59940357852882%
# Epoch Going 1: Loss = 530.2572, Accuracy = 62.59920634920635%
# Epoch Going 1: Loss = 531.1876, Accuracy = 62.605198019801975%
# Epoch Going 1: Loss = 532.1190, Accuracy = 62.6173418972332%
# Epoch Going 1: Loss = 532.9790, Accuracy = 62.632519723865876%
# Epoch Going 1: Loss = 533.8847, Accuracy = 62.64763779527559%
# Epoch Going 1: Loss = 534.8687, Accuracy = 62.65041748526523%
# Epoch Going 1: Loss = 535.7906, Accuracy = 62.66850490196079%
# Epoch Going 1: Loss = 536.9263, Accuracy = 62.65594422700587%
# Epoch Going 1: Loss = 537.9768, Accuracy = 62.6556396484375%
# Epoch Going 1: Loss = 539.1152, Accuracy = 62.64924463937622%
# Epoch Going 1: Loss = 540.3120, Accuracy = 62.64287451361867%
# Epoch Going 1: Loss = 541.3935, Accuracy = 62.64259708737864%
# Epoch Going 1: Loss = 542.4160, Accuracy = 62.645348837209305%
# Epoch Going 1: Loss = 543.5123, Accuracy = 62.64506769825918%
# Epoch Going 1: Loss = 544.7935, Accuracy = 62.6297055984556%
# Epoch Going 1: Loss = 545.9445, Accuracy = 62.602360308285164%
# Epoch Going 1: Loss = 546.8339, Accuracy = 62.60817307692308%
# Epoch Going 1: Loss = 547.7589, Accuracy = 62.62595969289827%
# Epoch Going 1: Loss = 548.7248, Accuracy = 62.63170498084292%
# Epoch Going 1: Loss = 549.6005, Accuracy = 62.652366156787764%
# Epoch Going 1: Loss = 550.4371, Accuracy = 62.664002862595424%
# Epoch Going 1: Loss = 551.2742, Accuracy = 62.68452380952381%
# Epoch Going 1: Loss = 552.2535, Accuracy = 62.68714353612167%
# Epoch Going 1: Loss = 553.1003, Accuracy = 62.704577798861486%
# Epoch Going 1: Loss = 554.1931, Accuracy = 62.6953125%
# Epoch Going 1: Loss = 555.1612, Accuracy = 62.69789697542533%
# Epoch Going 1: Loss = 556.2198, Accuracy = 62.691627358490564%
# Epoch Going 1: Loss = 557.2593, Accuracy = 62.70597928436912%
# Epoch Going 1: Loss = 558.2125, Accuracy = 62.71734022556391%
# Epoch Going 1: Loss = 559.1394, Accuracy = 62.72279549718574%
# Epoch Going 1: Loss = 559.9739, Accuracy = 62.74871254681648%
# Epoch Going 1: Loss = 560.9451, Accuracy = 62.754088785046726%
# Epoch Going 1: Loss = 562.0592, Accuracy = 62.74195429104478%
# Epoch Going 1: Loss = 563.0547, Accuracy = 62.744413407821234%
# Epoch Going 1: Loss = 564.1543, Accuracy = 62.75557620817844%
# Epoch Going 1: Loss = 565.2467, Accuracy = 62.75220315398887%
# Epoch Going 1: Loss = 566.2230, Accuracy = 62.74305555555556%
# Epoch Going 1: Loss = 567.3460, Accuracy = 62.73394177449168%
# Epoch Going 1: Loss = 568.5721, Accuracy = 62.707564575645755%
# Epoch Going 1: Loss = 569.7880, Accuracy = 62.6841620626151%
# Epoch Going 1: Loss = 570.9030, Accuracy = 62.66946231617647%
# Epoch Going 1: Loss = 571.9196, Accuracy = 62.65768348623853%
# Epoch Going 1: Loss = 572.7735, Accuracy = 62.686011904761905%
# Epoch Going 1: Loss = 573.7284, Accuracy = 62.69138482632541%
# Epoch Going 1: Loss = 574.6996, Accuracy = 62.68818430656934%
# Epoch Going 1: Loss = 575.8080, Accuracy = 62.67645719489982%
# Epoch Going 1: Loss = 576.9157, Accuracy = 62.684659090909086%
# Epoch Going 1: Loss = 577.8770, Accuracy = 62.692831215970955%
# Epoch Going 1: Loss = 579.1528, Accuracy = 62.68115942028986%
# Epoch Going 1: Loss = 580.1079, Accuracy = 62.68930831826401%
# Epoch Going 1: Loss = 580.9881, Accuracy = 62.69178700361011%
# Epoch Going 1: Loss = 581.8868, Accuracy = 62.70551801801801%
# Epoch Going 1: Loss = 582.7437, Accuracy = 62.72200989208633%
# Epoch Going 1: Loss = 583.6277, Accuracy = 62.73002692998204%
# Epoch Going 1: Loss = 584.6178, Accuracy = 62.74361559139785%
# Epoch Going 1: Loss = 585.8222, Accuracy = 62.73758944543828%
# Epoch Going 1: Loss = 586.9219, Accuracy = 62.72042410714286%
# Epoch Going 1: Loss = 587.9299, Accuracy = 62.7200311942959%
# Epoch Going 1: Loss = 589.0840, Accuracy = 62.705738434163706%
# Epoch Going 1: Loss = 589.9961, Accuracy = 62.71924955595026%
# Epoch Going 1: Loss = 591.2415, Accuracy = 62.705008865248224%
# Epoch Going 1: Loss = 592.3452, Accuracy = 62.696349557522126%
# Epoch Going 1: Loss = 593.5215, Accuracy = 62.7015238515901%
# Epoch Going 1: Loss = 594.5049, Accuracy = 62.714947089947096%
# Epoch Going 1: Loss = 595.4837, Accuracy = 62.7228213028169%
# Epoch Going 1: Loss = 596.6188, Accuracy = 62.72242970123023%
# Epoch Going 1: Loss = 597.7267, Accuracy = 62.71929824561403%
# Epoch Going 1: Loss = 599.0365, Accuracy = 62.70523204903677%
# Epoch Going 1: Loss = 599.8673, Accuracy = 62.72126311188811%
# Epoch Going 1: Loss = 600.8965, Accuracy = 62.718150087260035%
# Epoch Going 1: Loss = 601.8269, Accuracy = 62.73410278745645%
# Epoch Going 1: Loss = 602.7328, Accuracy = 62.74184782608696%
# Epoch Going 1: Loss = 603.9099, Accuracy = 62.73057725694444%
# Epoch Going 1: Loss = 604.8788, Accuracy = 62.72746967071057%
# Epoch Going 1: Loss = 605.8612, Accuracy = 62.72977941176471%
# Epoch Going 1: Loss = 606.8952, Accuracy = 62.72398531951641%
# Epoch Going 1: Loss = 607.7727, Accuracy = 62.72629310344827%
# Epoch Going 1: Loss = 608.6450, Accuracy = 62.74472891566265%
# Epoch Going 1: Loss = 609.5865, Accuracy = 62.75236254295533%
# Epoch Going 1: Loss = 610.7039, Accuracy = 62.743889365351635%
# Epoch Going 1: Loss = 611.8562, Accuracy = 62.7488227739726%
# Epoch Going 1: Loss = 612.8100, Accuracy = 62.745726495726494%
# Epoch Going 1: Loss = 613.9228, Accuracy = 62.74264078498294%
# Epoch Going 1: Loss = 614.8833, Accuracy = 62.7502129471891%
# Epoch Going 1: Loss = 615.9524, Accuracy = 62.755102040816325%
# Epoch Going 1: Loss = 617.0381, Accuracy = 62.76262733446519%
# Epoch Going 1: Loss = 618.0503, Accuracy = 62.76483050847458%
# Epoch Going 1: Loss = 619.2153, Accuracy = 62.7617385786802%
# Epoch Going 1: Loss = 620.2142, Accuracy = 62.76657516891891%
# Epoch Going 1: Loss = 621.2225, Accuracy = 62.77139544688028%
# Epoch Going 1: Loss = 622.3739, Accuracy = 62.768308080808076%
# Epoch Going 1: Loss = 623.2842, Accuracy = 62.778361344537814%
# Epoch Going 1: Loss = 624.2707, Accuracy = 62.77265100671141%
# Epoch Going 1: Loss = 625.2622, Accuracy = 62.7800460636516%
# Epoch Going 1: Loss = 626.2130, Accuracy = 62.79002926421404%
# Epoch Going 1: Loss = 627.2498, Accuracy = 62.78954507512521%
# Epoch Going 1: Loss = 628.2338, Accuracy = 62.78645833333333%
# Epoch Going 1: Loss = 629.2958, Accuracy = 62.79118136439268%
# Epoch Going 1: Loss = 630.3578, Accuracy = 62.79588870431893%
# Epoch Going 1: Loss = 631.3204, Accuracy = 62.80576285240465%
# Epoch Going 1: Loss = 632.4229, Accuracy = 62.81301738410596%
# Epoch Going 1: Loss = 633.5850, Accuracy = 62.802169421487605%
# Epoch Going 1: Loss = 634.5707, Accuracy = 62.79651402640264%
# Epoch Going 1: Loss = 635.5424, Accuracy = 62.81404448105437%
# Epoch Going 1: Loss = 636.6119, Accuracy = 62.8160978618421%
# Epoch Going 1: Loss = 637.6350, Accuracy = 62.81044745484401%
# Epoch Going 1: Loss = 638.6685, Accuracy = 62.81250000000001%
# Epoch Going 1: Loss = 639.6784, Accuracy = 62.80943126022913%
# Epoch Going 1: Loss = 640.6296, Accuracy = 62.82169117647059%
# Epoch Going 1: Loss = 641.8037, Accuracy = 62.81097063621534%
# Epoch Going 1: Loss = 642.8160, Accuracy = 62.82064332247557%
# Epoch Going 1: Loss = 644.0204, Accuracy = 62.81250000000001%
# Epoch Going 1: Loss = 645.0373, Accuracy = 62.8119926948052%
# Epoch Going 1: Loss = 646.4429, Accuracy = 62.786162884927066%
# Epoch Going 1: Loss = 647.2660, Accuracy = 62.79328478964401%
# Epoch Going 1: Loss = 648.1698, Accuracy = 62.80038368336026%
# Epoch Going 1: Loss = 649.1979, Accuracy = 62.794858870967744%
# Epoch Going 1: Loss = 650.2930, Accuracy = 62.79186795491143%
# Epoch Going 1: Loss = 651.4012, Accuracy = 62.778838424437296%
# Epoch Going 1: Loss = 652.1696, Accuracy = 62.79845505617978%
# Epoch Going 1: Loss = 653.4088, Accuracy = 62.785456730769226%
# Epoch Going 1: Loss = 654.3992, Accuracy = 62.79%
# Epoch Going 1: Loss = 655.5329, Accuracy = 62.78204872204473%
# Epoch Going 1: Loss = 656.4075, Accuracy = 62.79156698564593%
# Epoch Going 1: Loss = 657.4635, Accuracy = 62.78612659235668%
# Epoch Going 1: Loss = 658.6365, Accuracy = 62.77325119236884%
# Epoch Going 1: Loss = 659.5706, Accuracy = 62.78769841269841%
# Epoch Going 1: Loss = 660.8108, Accuracy = 62.772385103011096%
# Epoch Going 1: Loss = 661.7716, Accuracy = 62.76948180379747%
# Epoch Going 1: Loss = 662.8136, Accuracy = 62.7690560821485%
# Epoch Going 1: Loss = 664.0390, Accuracy = 62.76370268138801%
# Epoch Going 1: Loss = 664.8101, Accuracy = 62.785433070866134%
# Epoch Going 1: Loss = 665.9161, Accuracy = 62.782527515723274%
# Epoch Going 1: Loss = 666.8291, Accuracy = 62.786989795918366%
# Epoch Going 1: Loss = 667.8952, Accuracy = 62.786539968652036%
# Epoch Going 1: Loss = 668.9473, Accuracy = 62.78853677621284%
# Epoch Going 1: Loss = 669.6895, Accuracy = 62.81005859374999%
# Epoch Going 1: Loss = 670.5788, Accuracy = 62.80957488299532%
# Epoch Going 1: Loss = 671.6204, Accuracy = 62.79935747663551%
# Epoch Going 1: Loss = 672.3881, Accuracy = 62.82076205287714%
# Epoch Going 1: Loss = 673.6716, Accuracy = 62.793575310559%
# Epoch Going 1: Loss = 674.8986, Accuracy = 62.78343023255813%
# Epoch Going 1: Loss = 676.0401, Accuracy = 62.78057275541795%
# Epoch Going 1: Loss = 677.1863, Accuracy = 62.7728941267388%
# Epoch Going 1: Loss = 678.2344, Accuracy = 62.77006172839506%
# Epoch Going 1: Loss = 679.3193, Accuracy = 62.776868258859785%
# Epoch Going 1: Loss = 680.2009, Accuracy = 62.79326923076923%
# Epoch Going 1: Loss = 681.5131, Accuracy = 62.78321812596006%
# Epoch Going 1: Loss = 682.7474, Accuracy = 62.78038726993865%
# Epoch Going 1: Loss = 683.8387, Accuracy = 62.77756508422665%
# Epoch Going 1: Loss = 684.8623, Accuracy = 62.78430810397554%
# Epoch Going 1: Loss = 685.9348, Accuracy = 62.788645038167935%
# Epoch Going 1: Loss = 687.0104, Accuracy = 62.79296875%
# Epoch Going 1: Loss = 687.9691, Accuracy = 62.80679223744292%
# Epoch Going 1: Loss = 688.9954, Accuracy = 62.80632598784195%
# Epoch Going 1: Loss = 690.0142, Accuracy = 62.79874810318664%
# Epoch Going 1: Loss = 691.2209, Accuracy = 62.79356060606061%
# Epoch Going 1: Loss = 692.0275, Accuracy = 62.81202723146747%
# Epoch Going 1: Loss = 692.8396, Accuracy = 62.82571752265861%
# Epoch Going 1: Loss = 693.9845, Accuracy = 62.82522624434389%
# Epoch Going 1: Loss = 694.9939, Accuracy = 62.82708960843374%
# Epoch Going 1: Loss = 695.9978, Accuracy = 62.840695488721806%
# Epoch Going 1: Loss = 697.0068, Accuracy = 62.842530030030034%
# Epoch Going 1: Loss = 697.9218, Accuracy = 62.853729385307346%
# Epoch Going 1: Loss = 698.9643, Accuracy = 62.84852170658682%
# Epoch Going 1: Loss = 700.0531, Accuracy = 62.83398729446936%
# Epoch Going 1: Loss = 701.1510, Accuracy = 62.831156716417915%
# Epoch Going 1: Loss = 702.2491, Accuracy = 62.81902011922503%
# Epoch Going 1: Loss = 703.0858, Accuracy = 62.82319568452381%
# Epoch Going 1: Loss = 704.3247, Accuracy = 62.81342867756315%
# Epoch Going 1: Loss = 705.4788, Accuracy = 62.810645400593465%
# Epoch Going 1: Loss = 706.5347, Accuracy = 62.81712962962963%
# Epoch Going 1: Loss = 707.6024, Accuracy = 62.818971893491124%
# Epoch Going 1: Loss = 708.5507, Accuracy = 62.832348596750364%
# Epoch Going 1: Loss = 709.6182, Accuracy = 62.82955383480826%
# Epoch Going 1: Loss = 710.6579, Accuracy = 62.831369661266564%
# Epoch Going 1: Loss = 711.5925, Accuracy = 62.835477941176464%
# Epoch Going 1: Loss = 712.6811, Accuracy = 62.832690895741564%
# Epoch Going 1: Loss = 713.9050, Accuracy = 62.82303885630498%
# Epoch Going 1: Loss = 714.9250, Accuracy = 62.82714128843339%
# Epoch Going 1: Loss = 716.0831, Accuracy = 62.81524122807017%
# Epoch Going 1: Loss = 717.2748, Accuracy = 62.81021897810219%
# Epoch Going 1: Loss = 718.3677, Accuracy = 62.8143221574344%
# Epoch Going 1: Loss = 719.3758, Accuracy = 62.820687772925766%
# Epoch Going 1: Loss = 720.1688, Accuracy = 62.83839026162791%
# Epoch Going 1: Loss = 721.0179, Accuracy = 62.8583091436865%
# Epoch Going 1: Loss = 721.8831, Accuracy = 62.86911231884058%
# Epoch Going 1: Loss = 722.9911, Accuracy = 62.86405571635311%
# Epoch Going 1: Loss = 724.2813, Accuracy = 62.845466040462426%
# Epoch Going 1: Loss = 725.3411, Accuracy = 62.844967532467535%
# Epoch Going 1: Loss = 726.2784, Accuracy = 62.846721902017286%
# Epoch Going 1: Loss = 727.3708, Accuracy = 62.84847122302158%
# Epoch Going 1: Loss = 728.2384, Accuracy = 62.85246048850575%
# Epoch Going 1: Loss = 729.1282, Accuracy = 62.86540530846485%
# Epoch Going 1: Loss = 730.0891, Accuracy = 62.86935888252149%
# Epoch Going 1: Loss = 730.9548, Accuracy = 62.8755364806867%
# Epoch Going 1: Loss = 731.9078, Accuracy = 62.879464285714285%
# Epoch Going 1: Loss = 733.0410, Accuracy = 62.87000713266762%
# Epoch Going 1: Loss = 734.1138, Accuracy = 62.86280270655271%
# Epoch Going 1: Loss = 735.0556, Accuracy = 62.860064011379805%
# Epoch Going 1: Loss = 736.1938, Accuracy = 62.85733309659091%
# Epoch Going 1: Loss = 737.2302, Accuracy = 62.85239361702127%
# Epoch Going 1: Loss = 738.1818, Accuracy = 62.85410764872521%
# Epoch Going 1: Loss = 739.0026, Accuracy = 62.86023691654879%
# Epoch Going 1: Loss = 739.9060, Accuracy = 62.8707627118644%
# Epoch Going 1: Loss = 740.8209, Accuracy = 62.874647390691116%
# Epoch Going 1: Loss = 741.7240, Accuracy = 62.88292253521127%
# Epoch Going 1: Loss = 742.5936, Accuracy = 62.897767229254576%
# Epoch Going 1: Loss = 743.6148, Accuracy = 62.89720856741573%
# Epoch Going 1: Loss = 744.5007, Accuracy = 62.90103436185134%
# Epoch Going 1: Loss = 745.5812, Accuracy = 62.89390756302521%
# Epoch Going 1: Loss = 746.3260, Accuracy = 62.91958041958042%
# Epoch Going 1: Loss = 747.3044, Accuracy = 62.921176675977655%
# Epoch Going 1: Loss = 748.5476, Accuracy = 62.89661785216178%
# Epoch Going 1: Loss = 749.6181, Accuracy = 62.88083217270195%
# Epoch Going 1: Loss = 750.7557, Accuracy = 62.867263560500696%
# Epoch Going 1: Loss = 751.7844, Accuracy = 62.864583333333336%
# Epoch Going 1: Loss = 753.1637, Accuracy = 62.844573509015255%
# Epoch Going 1: Loss = 754.1978, Accuracy = 62.84193213296398%
# Epoch Going 1: Loss = 755.4255, Accuracy = 62.834975795297375%
# Epoch Going 1: Loss = 756.3231, Accuracy = 62.84530386740331%
# Epoch Going 1: Loss = 757.4130, Accuracy = 62.83405172413793%
# Epoch Going 1: Loss = 758.3889, Accuracy = 62.83574380165289%
# Epoch Going 1: Loss = 759.2371, Accuracy = 62.84172971114168%
# Epoch Going 1: Loss = 760.3983, Accuracy = 62.83052884615385%
# Epoch Going 1: Loss = 761.5693, Accuracy = 62.825788751714676%
# Epoch Going 1: Loss = 762.5898, Accuracy = 62.82320205479452%
# Epoch Going 1: Loss = 763.5511, Accuracy = 62.822759917920656%
# Epoch Going 1: Loss = 764.9698, Accuracy = 62.809511612021865%
# Epoch Going 1: Loss = 765.9037, Accuracy = 62.819747612551154%
# Epoch Going 1: Loss = 766.9192, Accuracy = 62.82569822888283%
# Epoch Going 1: Loss = 768.0914, Accuracy = 62.818877551020414%
# Epoch Going 1: Loss = 769.4444, Accuracy = 62.81419836956522%
# Epoch Going 1: Loss = 770.4921, Accuracy = 62.8158921302578%
# Epoch Going 1: Loss = 771.5739, Accuracy = 62.81758130081301%
# Epoch Going 1: Loss = 772.5819, Accuracy = 62.81926589986468%
# Epoch Going 1: Loss = 773.9341, Accuracy = 62.81672297297297%
# Epoch Going 1: Loss = 775.1723, Accuracy = 62.809969635627525%
# Epoch Going 1: Loss = 776.1780, Accuracy = 62.805340296495956%
# Epoch Going 1: Loss = 777.3160, Accuracy = 62.79651749663526%
# Epoch Going 1: Loss = 778.2047, Accuracy = 62.80871975806451%
# Epoch Going 1: Loss = 779.2090, Accuracy = 62.81879194630873%
# Epoch Going 1: Loss = 780.1957, Accuracy = 62.826742627345844%
# Epoch Going 1: Loss = 781.0552, Accuracy = 62.838855421686745%
# Epoch Going 1: Loss = 782.2155, Accuracy = 62.82169117647059%
# Epoch Going 1: Loss = 783.5347, Accuracy = 62.81083110814419%
# Epoch Going 1: Loss = 784.6134, Accuracy = 62.804166666666674%
# Epoch Going 1: Loss = 785.4627, Accuracy = 62.81416444740346%
# Epoch Going 1: Loss = 786.4456, Accuracy = 62.815824468085104%
# Epoch Going 1: Loss = 787.5475, Accuracy = 62.817480079681275%
# Epoch Going 1: Loss = 788.5116, Accuracy = 62.82120358090185%
# Epoch Going 1: Loss = 789.4825, Accuracy = 62.831125827814574%
# Epoch Going 1: Loss = 790.2688, Accuracy = 62.84515542328042%
# Epoch Going 1: Loss = 791.0949, Accuracy = 62.852955746367236%
# Epoch Going 1: Loss = 791.8629, Accuracy = 62.86691952506597%
# Epoch Going 1: Loss = 792.8444, Accuracy = 62.87055335968379%
# Epoch Going 1: Loss = 794.0801, Accuracy = 62.86800986842105%
# Epoch Going 1: Loss = 795.4842, Accuracy = 62.8428876478318%
# Epoch Going 1: Loss = 796.7234, Accuracy = 62.83218503937008%
# Epoch Going 1: Loss = 797.8064, Accuracy = 62.81536697247706%
# Epoch Going 1: Loss = 798.8326, Accuracy = 62.81290903141361%
# Epoch Going 1: Loss = 799.8246, Accuracy = 62.81658496732027%
# Epoch Going 1: Loss = 800.8165, Accuracy = 62.82433093994778%
# Epoch Going 1: Loss = 802.0974, Accuracy = 62.819833767926994%
# Epoch Going 1: Loss = 803.1721, Accuracy = 62.815348307291664%
# Epoch Going 1: Loss = 804.3080, Accuracy = 62.804778933680105%
# Epoch Going 1: Loss = 805.4395, Accuracy = 62.79829545454545%
# Epoch Going 1: Loss = 806.8421, Accuracy = 62.7837224383917%
# Epoch Going 1: Loss = 807.8434, Accuracy = 62.78537888601037%
# Epoch Going 1: Loss = 809.0517, Accuracy = 62.78298835705045%
# Epoch Going 1: Loss = 810.1733, Accuracy = 62.786660206718345%
# Epoch Going 1: Loss = 811.5874, Accuracy = 62.77620967741936%
# Epoch Going 1: Loss = 812.9397, Accuracy = 62.75571842783505%
# Epoch Going 1: Loss = 813.9887, Accuracy = 62.757400257400256%
# Epoch Going 1: Loss = 814.9420, Accuracy = 62.773136246786635%
# Epoch Going 1: Loss = 815.9242, Accuracy = 62.77880295250321%
# ...
# Epoch Going 15: Loss = 646.6866, Accuracy = 66.2956204379562%
# Epoch Going 15: Loss = 647.5547, Accuracy = 66.29919825072886%
# Epoch Going 15: Loss = 648.5280, Accuracy = 66.30049126637554%
# Epoch Going 15: Loss = 649.3805, Accuracy = 66.3040515988372%
# Epoch Going 15: Loss = 650.4294, Accuracy = 66.2962626995646%
# Epoch Going 15: Loss = 651.1909, Accuracy = 66.30661231884058%
# Epoch Going 15: Loss = 652.3368, Accuracy = 66.29658104196817%
# Epoch Going 15: Loss = 653.2129, Accuracy = 66.29335260115607%
# Epoch Going 15: Loss = 654.1870, Accuracy = 66.2856240981241%
# Epoch Going 15: Loss = 654.9275, Accuracy = 66.29818083573487%
# Epoch Going 15: Loss = 655.8436, Accuracy = 66.29946043165468%
# Epoch Going 15: Loss = 656.7636, Accuracy = 66.30073635057471%
# Epoch Going 15: Loss = 657.6701, Accuracy = 66.30200860832137%
# Epoch Going 15: Loss = 658.6074, Accuracy = 66.30551575931231%
# Epoch Going 15: Loss = 659.3343, Accuracy = 66.32242489270385%
# Epoch Going 15: Loss = 660.2661, Accuracy = 66.32589285714286%
# Epoch Going 15: Loss = 661.2928, Accuracy = 66.32489300998573%
# Epoch Going 15: Loss = 662.0401, Accuracy = 66.33947649572649%
# Epoch Going 15: Loss = 663.1107, Accuracy = 66.3429054054054%
# Epoch Going 15: Loss = 664.2053, Accuracy = 66.3418856534091%
# Epoch Going 15: Loss = 665.4808, Accuracy = 66.32313829787235%
# Epoch Going 15: Loss = 666.7942, Accuracy = 66.31550991501416%
# Epoch Going 15: Loss = 667.7546, Accuracy = 66.31453323903818%
# Epoch Going 15: Loss = 668.8730, Accuracy = 66.31135240112994%
# Epoch Going 15: Loss = 669.7961, Accuracy = 66.31038434414668%
# Epoch Going 15: Loss = 670.5569, Accuracy = 66.3138204225352%
# Epoch Going 15: Loss = 671.4709, Accuracy = 66.31724683544303%
# Epoch Going 15: Loss = 672.5441, Accuracy = 66.31627457865169%
# Epoch Going 15: Loss = 673.6421, Accuracy = 66.30653927068724%
# Epoch Going 15: Loss = 674.5650, Accuracy = 66.30996148459384%
# Epoch Going 15: Loss = 675.2891, Accuracy = 66.31993006993007%
# Epoch Going 15: Loss = 676.1956, Accuracy = 66.3189594972067%
# Epoch Going 15: Loss = 677.0026, Accuracy = 66.32235006973501%
# Epoch Going 15: Loss = 677.9479, Accuracy = 66.32573119777159%
# Epoch Going 15: Loss = 678.8514, Accuracy = 66.33127607788595%
# Epoch Going 15: Loss = 680.0389, Accuracy = 66.32595486111111%
# Epoch Going 15: Loss = 680.8941, Accuracy = 66.32714979195562%
# Epoch Going 15: Loss = 681.9151, Accuracy = 66.32184903047091%
# Epoch Going 15: Loss = 683.0148, Accuracy = 66.31007952973721%
# Epoch Going 15: Loss = 683.9819, Accuracy = 66.30913328729282%
# Epoch Going 15: Loss = 685.0230, Accuracy = 66.30387931034483%
# Epoch Going 15: Loss = 685.7503, Accuracy = 66.30724862258953%
# Epoch Going 15: Loss = 686.8688, Accuracy = 66.30201169188446%
# Epoch Going 15: Loss = 687.7639, Accuracy = 66.31395947802197%
# Epoch Going 15: Loss = 688.7003, Accuracy = 66.30444101508917%
# Epoch Going 15: Loss = 689.6093, Accuracy = 66.2992294520548%
# Epoch Going 15: Loss = 690.7947, Accuracy = 66.28548221614227%
# Epoch Going 15: Loss = 691.7152, Accuracy = 66.29525273224044%
# Epoch Going 15: Loss = 692.6359, Accuracy = 66.2943383356071%
# Epoch Going 15: Loss = 693.7284, Accuracy = 66.29768392370572%
# Epoch Going 15: Loss = 694.7593, Accuracy = 66.2861394557823%
# Epoch Going 15: Loss = 696.0766, Accuracy = 66.2682574728261%
# Epoch Going 15: Loss = 696.9824, Accuracy = 66.26738466757124%
# Epoch Going 15: Loss = 697.9673, Accuracy = 66.27286585365853%
# Epoch Going 15: Loss = 698.7808, Accuracy = 66.27198917456022%
# Epoch Going 15: Loss = 699.7432, Accuracy = 66.2647804054054%
# Epoch Going 15: Loss = 700.9192, Accuracy = 66.25759109311741%
# Epoch Going 15: Loss = 701.8840, Accuracy = 66.24199797843666%
# Epoch Going 15: Loss = 702.6939, Accuracy = 66.2495794078062%
# Epoch Going 15: Loss = 703.7069, Accuracy = 66.24453965053763%
# Epoch Going 15: Loss = 704.9715, Accuracy = 66.23741610738256%
# Epoch Going 15: Loss = 705.7940, Accuracy = 66.24916219839142%
# Epoch Going 15: Loss = 706.7485, Accuracy = 66.24414323962516%
# Epoch Going 15: Loss = 707.9548, Accuracy = 66.23704879679144%
# Epoch Going 15: Loss = 708.7874, Accuracy = 66.24666221628839%
# Epoch Going 15: Loss = 709.7945, Accuracy = 66.23750000000001%
# Epoch Going 15: Loss = 710.6917, Accuracy = 66.24500665778962%
# Epoch Going 15: Loss = 711.6059, Accuracy = 66.24210438829788%
# Epoch Going 15: Loss = 712.4695, Accuracy = 66.2433598937583%
# Epoch Going 15: Loss = 713.4579, Accuracy = 66.2425397877984%
# Epoch Going 15: Loss = 714.5012, Accuracy = 66.25%
# Epoch Going 15: Loss = 715.3490, Accuracy = 66.25330687830689%
# Epoch Going 15: Loss = 716.1461, Accuracy = 66.25866908850726%
# Epoch Going 15: Loss = 717.3913, Accuracy = 66.24546503957784%
# Epoch Going 15: Loss = 718.2701, Accuracy = 66.24670619235836%
# Epoch Going 15: Loss = 719.1688, Accuracy = 66.24794407894737%
# Epoch Going 15: Loss = 720.1282, Accuracy = 66.24507227332457%
# Epoch Going 15: Loss = 721.0220, Accuracy = 66.24220800524935%
# Epoch Going 15: Loss = 722.2973, Accuracy = 66.22501638269986%
# Epoch Going 15: Loss = 723.3113, Accuracy = 66.21605039267016%
# Epoch Going 15: Loss = 724.4172, Accuracy = 66.19893790849673%
# Epoch Going 15: Loss = 725.4969, Accuracy = 66.19818864229765%
# Epoch Going 15: Loss = 726.6275, Accuracy = 66.18521838331161%
# Epoch Going 15: Loss = 727.5188, Accuracy = 66.192626953125%
# Epoch Going 15: Loss = 728.3172, Accuracy = 66.21017555266579%
# Epoch Going 15: Loss = 729.3985, Accuracy = 66.20738636363637%
# Epoch Going 15: Loss = 730.3565, Accuracy = 66.19852464332037%
# Epoch Going 15: Loss = 731.2645, Accuracy = 66.19980569948186%
# Epoch Going 15: Loss = 732.2834, Accuracy = 66.1869340232859%
# Epoch Going 15: Loss = 733.4220, Accuracy = 66.17207687338501%
# Epoch Going 15: Loss = 734.2151, Accuracy = 66.1774193548387%
# Epoch Going 15: Loss = 735.3794, Accuracy = 66.1706668814433%
# Epoch Going 15: Loss = 736.2658, Accuracy = 66.17800836550836%
# Epoch Going 15: Loss = 737.1694, Accuracy = 66.18332262210797%
# Epoch Going 15: Loss = 738.2832, Accuracy = 66.17658857509628%
# Epoch Going 15: Loss = 739.2457, Accuracy = 66.1738782051282%
# Epoch Going 15: Loss = 740.1711, Accuracy = 66.16717349551855%
# Epoch Going 15: Loss = 740.9274, Accuracy = 66.1824648337596%
# Epoch Going 15: Loss = 741.9961, Accuracy = 66.17377075351213%
# Epoch Going 15: Loss = 742.9513, Accuracy = 66.17307079081633%
# Epoch Going 15: Loss = 743.9082, Accuracy = 66.16441082802548%
# Epoch Going 15: Loss = 744.7717, Accuracy = 66.1696882951654%
# Epoch Going 15: Loss = 745.9191, Accuracy = 66.16304002541295%
# Epoch Going 15: Loss = 746.8941, Accuracy = 66.16235723350253%
# Epoch Going 15: Loss = 747.6634, Accuracy = 66.17157794676805%
# Epoch Going 15: Loss = 748.6490, Accuracy = 66.1689082278481%
# Epoch Going 15: Loss = 749.5448, Accuracy = 66.1662452591656%
# Epoch Going 15: Loss = 750.8210, Accuracy = 66.15767045454545%
# Epoch Going 15: Loss = 751.9074, Accuracy = 66.14911727616646%
# Epoch Going 15: Loss = 752.9100, Accuracy = 66.14648929471034%
# Epoch Going 15: Loss = 753.9468, Accuracy = 66.13600628930818%
# Epoch Going 15: Loss = 755.1652, Accuracy = 66.12358668341709%
# Epoch Going 15: Loss = 755.9747, Accuracy = 66.13668444165621%
# Epoch Going 15: Loss = 756.8961, Accuracy = 66.13995927318295%
# Epoch Going 15: Loss = 757.8716, Accuracy = 66.13149249061327%
# Epoch Going 15: Loss = 758.7930, Accuracy = 66.123046875%
# Epoch Going 15: Loss = 759.9581, Accuracy = 66.12242509363297%
# Epoch Going 15: Loss = 760.9425, Accuracy = 66.11790835411472%
# Epoch Going 15: Loss = 761.9137, Accuracy = 66.1192403486924%
# Epoch Going 15: Loss = 763.0300, Accuracy = 66.11862562189054%
# Epoch Going 15: Loss = 763.8751, Accuracy = 66.12189440993788%
# Epoch Going 15: Loss = 764.6167, Accuracy = 66.13290942928039%
# Epoch Going 15: Loss = 765.6526, Accuracy = 66.12453531598513%
# Epoch Going 15: Loss = 766.6737, Accuracy = 66.12198329207921%
# Epoch Going 15: Loss = 767.6305, Accuracy = 66.13295735475896%
# Epoch Going 15: Loss = 768.4926, Accuracy = 66.13425925925925%
# Epoch Going 15: Loss = 769.4575, Accuracy = 66.13748458692972%
# Epoch Going 15: Loss = 770.3764, Accuracy = 66.14455049261085%
# Epoch Going 15: Loss = 771.4163, Accuracy = 66.14198954489545%
# Epoch Going 15: Loss = 772.3646, Accuracy = 66.13751535626535%
# Epoch Going 15: Loss = 773.3848, Accuracy = 66.13113496932516%
# Epoch Going 15: Loss = 774.3340, Accuracy = 66.12859987745098%
# Epoch Going 15: Loss = 775.2854, Accuracy = 66.12607099143207%
# Epoch Going 15: Loss = 776.3227, Accuracy = 66.12545843520783%
# Epoch Going 15: Loss = 777.1785, Accuracy = 66.12675518925519%
# Epoch Going 15: Loss = 778.0220, Accuracy = 66.12614329268293%
# Epoch Going 15: Loss = 778.7075, Accuracy = 66.1388550548112%
# Epoch Going 15: Loss = 779.8214, Accuracy = 66.12872566909975%
# Epoch Going 15: Loss = 780.5440, Accuracy = 66.13760631834751%
# Epoch Going 15: Loss = 781.4314, Accuracy = 66.1350879854369%
# Epoch Going 15: Loss = 782.2470, Accuracy = 66.14204545454545%
# Epoch Going 15: Loss = 782.9539, Accuracy = 66.15087772397095%
# Epoch Going 15: Loss = 783.8220, Accuracy = 66.15213119709794%
# Epoch Going 15: Loss = 784.8754, Accuracy = 66.15526871980676%
# Epoch Going 15: Loss = 785.9327, Accuracy = 66.15274427020506%
# Epoch Going 15: Loss = 786.9913, Accuracy = 66.144578313253%
# Epoch Going 15: Loss = 788.0579, Accuracy = 66.13455174488568%
# Epoch Going 15: Loss = 789.0201, Accuracy = 66.14145132211539%
# Epoch Going 15: Loss = 789.8426, Accuracy = 66.14833433373349%
# Epoch Going 15: Loss = 791.1763, Accuracy = 66.130845323741%
# Epoch Going 15: Loss = 792.0927, Accuracy = 66.13398203592814%
# Epoch Going 15: Loss = 793.0044, Accuracy = 66.14084928229666%
# Epoch Going 15: Loss = 793.8616, Accuracy = 66.14023297491039%
# Epoch Going 15: Loss = 794.8946, Accuracy = 66.14148269689738%
# Epoch Going 15: Loss = 795.9799, Accuracy = 66.13155542312276%
# Epoch Going 15: Loss = 797.0112, Accuracy = 66.13653273809523%
# Epoch Going 15: Loss = 797.8895, Accuracy = 66.14149821640903%
# Epoch Going 15: Loss = 798.9862, Accuracy = 66.13531769596199%
# Epoch Going 15: Loss = 799.8474, Accuracy = 66.13285883748517%
# Epoch Going 15: Loss = 800.8225, Accuracy = 66.12855450236967%
# Epoch Going 15: Loss = 801.8452, Accuracy = 66.1298076923077%
# Epoch Going 15: Loss = 802.6323, Accuracy = 66.1365986997636%
# Epoch Going 15: Loss = 803.4420, Accuracy = 66.14337367178277%
# Epoch Going 15: Loss = 804.3070, Accuracy = 66.15381780660378%
# Epoch Going 15: Loss = 805.1775, Accuracy = 66.15871613663134%
# Epoch Going 15: Loss = 806.0035, Accuracy = 66.15625%
# Epoch Going 15: Loss = 806.7376, Accuracy = 66.16847826086956%
# Epoch Going 15: Loss = 807.8300, Accuracy = 66.16600645539906%
# Epoch Going 15: Loss = 808.6557, Accuracy = 66.17269929660023%
# Epoch Going 15: Loss = 809.5319, Accuracy = 66.17937646370024%
# Epoch Going 15: Loss = 810.6359, Accuracy = 66.17141812865496%
# Epoch Going 15: Loss = 811.6353, Accuracy = 66.16347838785047%
# Epoch Going 15: Loss = 812.5309, Accuracy = 66.15555717619603%
# Epoch Going 15: Loss = 813.5729, Accuracy = 66.14583333333334%
# Epoch Going 15: Loss = 814.4913, Accuracy = 66.145227008149%
# Epoch Going 15: Loss = 815.3600, Accuracy = 66.14643895348837%
# Epoch Going 15: Loss = 816.2472, Accuracy = 66.14946283391406%
# Epoch Going 15: Loss = 817.0704, Accuracy = 66.15429234338747%
# Epoch Going 15: Loss = 818.0818, Accuracy = 66.14462630359212%
# Epoch Going 15: Loss = 819.0937, Accuracy = 66.14040798611111%
# Epoch Going 15: Loss = 819.9928, Accuracy = 66.14342485549133%
# Epoch Going 15: Loss = 821.1348, Accuracy = 66.13380484988453%
# Epoch Going 15: Loss = 821.9595, Accuracy = 66.13321799307958%
# Epoch Going 15: Loss = 823.0524, Accuracy = 66.12543202764977%
# Epoch Going 15: Loss = 823.8673, Accuracy = 66.13204833141542%
# Epoch Going 15: Loss = 824.7493, Accuracy = 66.12966954022988%
# Epoch Going 15: Loss = 825.7264, Accuracy = 66.12729621125143%
# Epoch Going 15: Loss = 826.4870, Accuracy = 66.13209575688074%
# Epoch Going 15: Loss = 827.3663, Accuracy = 66.1368843069874%
# Epoch Going 15: Loss = 828.1152, Accuracy = 66.14881292906179%
# Epoch Going 15: Loss = 829.1706, Accuracy = 66.14999999999999%
# Epoch Going 15: Loss = 830.0750, Accuracy = 66.15475171232876%
# Epoch Going 15: Loss = 831.0281, Accuracy = 66.15414766248576%
# Epoch Going 15: Loss = 832.1243, Accuracy = 66.15176537585421%
# Epoch Going 15: Loss = 832.8169, Accuracy = 66.16005403868031%
# Epoch Going 15: Loss = 833.6724, Accuracy = 66.1612215909091%
# Epoch Going 15: Loss = 834.6335, Accuracy = 66.15883938706017%
# Epoch Going 15: Loss = 835.7569, Accuracy = 66.14937641723357%
# Epoch Going 15: Loss = 836.6989, Accuracy = 66.1487825594564%
# Epoch Going 15: Loss = 837.5185, Accuracy = 66.15349264705883%
# Epoch Going 15: Loss = 838.4925, Accuracy = 66.14936440677967%
# Epoch Going 15: Loss = 839.6813, Accuracy = 66.13642776523702%
# Epoch Going 15: Loss = 840.5857, Accuracy = 66.13056651634723%
# Epoch Going 15: Loss = 841.6039, Accuracy = 66.12647804054053%
# Epoch Going 15: Loss = 842.5331, Accuracy = 66.13118672665917%
# Epoch Going 15: Loss = 843.7383, Accuracy = 66.12359550561798%
# Epoch Going 15: Loss = 844.6765, Accuracy = 66.11952861952862%
# Epoch Going 15: Loss = 845.6936, Accuracy = 66.11371917040358%
# Epoch Going 15: Loss = 846.7177, Accuracy = 66.11667133258679%
# Epoch Going 15: Loss = 847.6280, Accuracy = 66.1091303131991%
# Epoch Going 15: Loss = 848.3744, Accuracy = 66.11208100558659%
# Epoch Going 15: Loss = 849.4784, Accuracy = 66.11502511160714%
# Epoch Going 15: Loss = 850.4943, Accuracy = 66.11273690078038%
# Epoch Going 15: Loss = 851.6593, Accuracy = 66.11219376391982%
# Epoch Going 15: Loss = 852.5070, Accuracy = 66.1168659621802%
# Epoch Going 15: Loss = 853.4690, Accuracy = 66.11284722222223%
# Epoch Going 15: Loss = 854.4939, Accuracy = 66.10536903440621%
# Epoch Going 15: Loss = 855.5461, Accuracy = 66.09617516629712%
# Epoch Going 15: Loss = 856.4103, Accuracy = 66.09392303433002%
# Epoch Going 15: Loss = 857.3722, Accuracy = 66.09686117256636%
# Epoch Going 15: Loss = 858.1967, Accuracy = 66.10151933701658%
# Epoch Going 15: Loss = 859.2892, Accuracy = 66.10616721854305%
# Epoch Going 15: Loss = 860.3012, Accuracy = 66.09530044101433%
# Epoch Going 15: Loss = 861.2737, Accuracy = 66.09134085903084%
# Epoch Going 15: Loss = 862.0442, Accuracy = 66.09770352035204%
# Epoch Going 15: Loss = 863.1213, Accuracy = 66.09203296703296%
# Epoch Going 15: Loss = 864.0861, Accuracy = 66.08809001097696%
# Epoch Going 15: Loss = 865.2165, Accuracy = 66.07730263157895%
# Epoch Going 15: Loss = 866.3777, Accuracy = 66.05798192771084%
# Epoch Going 15: Loss = 867.3508, Accuracy = 66.06434628008753%
# Epoch Going 15: Loss = 868.3126, Accuracy = 66.05874316939891%
# Epoch Going 15: Loss = 869.2169, Accuracy = 66.05315229257643%
# Epoch Going 15: Loss = 870.3681, Accuracy = 66.04586968375136%
# Epoch Going 15: Loss = 871.3630, Accuracy = 66.03519880174292%
# Epoch Going 15: Loss = 872.1539, Accuracy = 66.0381528835691%
# Epoch Going 15: Loss = 873.3242, Accuracy = 66.02921195652173%
# Epoch Going 15: Loss = 874.1539, Accuracy = 66.0321661237785%
# Epoch Going 15: Loss = 875.2055, Accuracy = 66.02664045553145%
# Epoch Going 15: Loss = 876.1195, Accuracy = 66.02620530877573%
# Epoch Going 15: Loss = 877.2950, Accuracy = 66.02238906926407%
# Epoch Going 15: Loss = 878.1458, Accuracy = 66.02364864864865%
# Epoch Going 15: Loss = 879.2031, Accuracy = 66.011406587473%
# Epoch Going 15: Loss = 880.0581, Accuracy = 66.01436084142395%
# Epoch Going 15: Loss = 880.9381, Accuracy = 66.01730872844827%
# Epoch Going 15: Loss = 881.9901, Accuracy = 66.01015877287406%
# Epoch Going 15: Loss = 882.6968, Accuracy = 66.0198252688172%
# Epoch Going 15: Loss = 883.5981, Accuracy = 66.01604457572503%
# Epoch Going 15: Loss = 884.4118, Accuracy = 66.02065450643777%
# Epoch Going 15: Loss = 885.3724, Accuracy = 66.01855573419078%
# Epoch Going 15: Loss = 886.3531, Accuracy = 66.01646145610277%
# Epoch Going 15: Loss = 887.5029, Accuracy = 66.01270053475936%
# Epoch Going 15: Loss = 888.5588, Accuracy = 66.00894764957265%
# Epoch Going 15: Loss = 889.5158, Accuracy = 66.00687033084311%
# Epoch Going 15: Loss = 890.3532, Accuracy = 66.01166666666667%
# Epoch 15: Loss = 0.9492, Accuracy = 66.01%

# %%
checkpoint_path = 'resnet_fashion_checkpoint.pth'

    # Save the model checkpoint
torch.save({
    'epoch': epoch,
    'model_state_dict': resnet_model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'loss': running_loss / len(train_loader),
    }, checkpoint_path)
