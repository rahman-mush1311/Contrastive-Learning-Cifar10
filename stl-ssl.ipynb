# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
from torch.utils.data import DataLoader

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp38-cp38-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\anaconda3\envs\gputest\lib\site-packages (from scikit-learn) (1.23.2)
# Collecting scipy>=1.5.0 (from scikit-learn)
#   Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata (58 kB)
#      ---------------------------------------- 0.0/59.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/59.0 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 59.0/59.0 kB 624.8 kB/s eta 0:00:00
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Downloading joblib-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.3.2-cp38-cp38-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/9.3 MB 18.2 MB/s eta 0:00:01
#    ------- -------------------------------- 1.8/9.3 MB 23.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.8/9.3 MB 30.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.7/9.3 MB 35.5 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.3 MB 42.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 39.4 MB/s eta 0:00:00
# Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.2 kB ? eta -:--:--
#    ---------------------------------------- 301.2/301.2 kB ? eta 0:00:00
# Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
#    ---------------------------------------- 0.0/42.2 MB ? eta -:--:--
#    --- ------------------------------------ 4.0/42.2 MB 85.6 MB/s eta 0:00:01
#    ------ --------------------------------- 7.2/42.2 MB 76.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 11.7/42.2 MB 93.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 18.0/42.2 MB 131.2 MB/s eta 0:00:01
#    --------------------- ------------------ 22.6/42.2 MB 93.9 MB/s eta 0:00:01
#    -------------------------- ------------- 27.8/42.2 MB 108.8 MB/s eta 0:00:01
#    ------------------------------- -------- 32.8/42.2 MB 93.0 MB/s eta 0:00:01
#    ------------------------------------ --- 38.3/42.2 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------- 42.2/42.2 MB 65.5 MB/s eta 0:00:00
# Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.0 scikit-learn-1.3.2 scipy-1.10.1 threadpoolctl-3.4.0

# %%
# !pip install torchsummary
# Out:
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl.metadata (296 bytes)
# Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1

# %%
def ResNet18SimCLR():
    resnet = models.resnet18(pretrained=False)
    resnet.fc = nn.Identity()  # Remove the fully connected layer
    return resnet

# %%
def augment(x):
    transform = transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomApply([transforms.ColorJitter(0.8, 0.8, 0.8, 0.2)], p=0.8),
    ])
    x = torch.stack([transform(img) for img in x])
    return x

# %%
def projection_head(x_tuple, hidden_dim=256,device=torch.device("cuda" if torch.cuda.is_available() else "cpu")):
    flattened_tensors = [tensor.flatten(start_dim=1) for tensor in x_tuple]
    # Concatenate the flattened tensors along dimension 1
    concatenated_tensor = torch.cat(flattened_tensors, dim=1)
    projection = nn.Sequential(
        nn.Linear(concatenated_tensor.shape[1], hidden_dim),
        nn.ReLU(inplace=True),
        nn.Linear(hidden_dim, hidden_dim),
    ).to(device)  # Move projection head to the correct device
    return projection(concatenated_tensor)

# %%
def NTXentLoss(z1, z2, temperature=0.5):
    N = z1.size(0)
    z = torch.cat([z1, z2], dim=0)
    sim = torch.mm(z, z.t()) / (torch.norm(z, dim=1, keepdim=True) * torch.norm(z.t(), dim=0, keepdim=True))
    sim = sim / temperature
    sim_exp = torch.exp(sim)
    sim_exp = sim_exp - torch.eye(2 * N, device=z.device)
    sim_1_2 = sim_exp[:N, N:]
    sim_2_1 = sim_exp[N:, :N]
    sim_1_1 = sim_exp[:N, :N]
    sim_2_2 = sim_exp[N:, N:]

    loss = -(torch.log(sim_1_2.sum(dim=1) / (sim_1_1.sum(dim=1) + sim_1_2.sum(dim=1))).mean() +
             torch.log(sim_2_1.sum(dim=1) / (sim_2_1.sum(dim=1) + sim_2_2.sum(dim=1))).mean()) / 2
    return loss

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])
train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=4)
# Out:
# Files already downloaded and verified

# %%
resnet_model = ResNet18SimCLR().to(device)

# Optimizer
optimizer = optim.Adam(resnet_model.parameters(), lr=3e-4)

# %%
num_epochs = 15
temperature = 0.5
for epoch in range(num_epochs):
    total_loss = 0.0
    bs=0
    for i, (images, _) in enumerate(train_loader):
        images = images.to(device)

        # Forward pass
        images_aug1 = augment(images).to(device)
        images_aug2 = augment(images).to(device)

        features1 = projection_head((resnet_model(images_aug1),), device=device)
        features2 = projection_head((resnet_model(images_aug2),), device=device)

        # Calculate loss
        loss = NTXentLoss(features1, features2, temperature)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        print(f"batch [{bs}],Epoch going [{epoch}], Loss: {total_loss}")
        bs+=1
    # Print epoch loss
    print(f"epoch[{epoch+1}/{num_epochs}], Loss: {total_loss / len(train_loader):.4f}")
   
    #model checkpoint
    checkpoint_path = 'resnet_simclr_checkpoint.pth'

    # Save the model checkpoint
    torch.save({
    'epoch': epoch,
    'model_state_dict': resnet_model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'loss': total_loss / len(train_loader),
    }, checkpoint_path)
# Out:
# batch [0],Epoch going [0], Loss: 1.8111889362335205
# batch [1],Epoch going [0], Loss: 3.5674052238464355
# batch [2],Epoch going [0], Loss: 5.431925535202026
# batch [3],Epoch going [0], Loss: 7.099295139312744
# batch [4],Epoch going [0], Loss: 8.845873594284058
# batch [5],Epoch going [0], Loss: 10.483515977859497
# batch [6],Epoch going [0], Loss: 12.029024362564087
# batch [7],Epoch going [0], Loss: 13.698266744613647
# batch [8],Epoch going [0], Loss: 15.2481369972229
# batch [9],Epoch going [0], Loss: 16.820189237594604
# batch [10],Epoch going [0], Loss: 18.484810948371887
# batch [11],Epoch going [0], Loss: 20.04108726978302
# batch [12],Epoch going [0], Loss: 21.51816189289093
# batch [13],Epoch going [0], Loss: 23.08226776123047
# batch [14],Epoch going [0], Loss: 24.571635961532593
# batch [15],Epoch going [0], Loss: 26.0511292219162
# batch [16],Epoch going [0], Loss: 27.569857954978943
# batch [17],Epoch going [0], Loss: 29.075791001319885
# batch [18],Epoch going [0], Loss: 30.685845494270325
# batch [19],Epoch going [0], Loss: 32.108197808265686
# batch [20],Epoch going [0], Loss: 33.579655170440674
# batch [21],Epoch going [0], Loss: 35.10744547843933
# batch [22],Epoch going [0], Loss: 36.62097787857056
# batch [23],Epoch going [0], Loss: 38.02433097362518
# batch [24],Epoch going [0], Loss: 39.62865149974823
# batch [25],Epoch going [0], Loss: 41.21273362636566
# batch [26],Epoch going [0], Loss: 42.739405274391174
# batch [27],Epoch going [0], Loss: 44.13804638385773
# batch [28],Epoch going [0], Loss: 45.464470982551575
# batch [29],Epoch going [0], Loss: 46.86808168888092
# batch [30],Epoch going [0], Loss: 48.28484833240509
# batch [31],Epoch going [0], Loss: 49.82090675830841
# batch [32],Epoch going [0], Loss: 51.17802619934082
# batch [33],Epoch going [0], Loss: 52.691768169403076
# batch [34],Epoch going [0], Loss: 54.13250184059143
# batch [35],Epoch going [0], Loss: 55.5201051235199
# batch [36],Epoch going [0], Loss: 56.95384895801544
# batch [37],Epoch going [0], Loss: 58.42735016345978
# batch [38],Epoch going [0], Loss: 59.865564465522766
# batch [39],Epoch going [0], Loss: 61.32974064350128
# batch [40],Epoch going [0], Loss: 62.77096331119537
# batch [41],Epoch going [0], Loss: 64.23544228076935
# batch [42],Epoch going [0], Loss: 65.74193966388702
# batch [43],Epoch going [0], Loss: 67.17622315883636
# batch [44],Epoch going [0], Loss: 68.65055072307587
# batch [45],Epoch going [0], Loss: 69.9783079624176
# batch [46],Epoch going [0], Loss: 71.293914437294
# batch [47],Epoch going [0], Loss: 72.7742167711258
# batch [48],Epoch going [0], Loss: 74.23067212104797
# batch [49],Epoch going [0], Loss: 75.69162774085999
# batch [50],Epoch going [0], Loss: 77.1342887878418
# batch [51],Epoch going [0], Loss: 78.45442068576813
# batch [52],Epoch going [0], Loss: 79.67063295841217
# batch [53],Epoch going [0], Loss: 81.01715695858002
# batch [54],Epoch going [0], Loss: 82.48986065387726
# batch [55],Epoch going [0], Loss: 83.96188771724701
# batch [56],Epoch going [0], Loss: 85.32173907756805
# batch [57],Epoch going [0], Loss: 86.62833666801453
# batch [58],Epoch going [0], Loss: 88.07749104499817
# batch [59],Epoch going [0], Loss: 89.32312190532684
# batch [60],Epoch going [0], Loss: 90.78259706497192
# batch [61],Epoch going [0], Loss: 92.1969645023346
# batch [62],Epoch going [0], Loss: 93.6450525522232
# batch [63],Epoch going [0], Loss: 95.05319941043854
# batch [64],Epoch going [0], Loss: 96.47718298435211
# batch [65],Epoch going [0], Loss: 97.85569894313812
# batch [66],Epoch going [0], Loss: 99.12925291061401
# batch [67],Epoch going [0], Loss: 100.61186528205872
# batch [68],Epoch going [0], Loss: 101.84279012680054
# batch [69],Epoch going [0], Loss: 103.2082998752594
# batch [70],Epoch going [0], Loss: 104.55908024311066
# batch [71],Epoch going [0], Loss: 105.8476494550705
# batch [72],Epoch going [0], Loss: 107.26119792461395
# batch [73],Epoch going [0], Loss: 108.51110780239105
# batch [74],Epoch going [0], Loss: 109.73819124698639
# batch [75],Epoch going [0], Loss: 111.14784944057465
# batch [76],Epoch going [0], Loss: 112.52296721935272
# batch [77],Epoch going [0], Loss: 113.91573512554169
# batch [78],Epoch going [0], Loss: 115.2963844537735
# batch [79],Epoch going [0], Loss: 116.5721982717514
# batch [80],Epoch going [0], Loss: 117.96368217468262
# batch [81],Epoch going [0], Loss: 119.3738043308258
# batch [82],Epoch going [0], Loss: 120.70916616916656
# batch [83],Epoch going [0], Loss: 122.04230988025665
# batch [84],Epoch going [0], Loss: 123.41152441501617
# batch [85],Epoch going [0], Loss: 124.79945957660675
# batch [86],Epoch going [0], Loss: 126.09178483486176
# batch [87],Epoch going [0], Loss: 127.47099828720093
# batch [88],Epoch going [0], Loss: 128.80025124549866
# batch [89],Epoch going [0], Loss: 130.10846412181854
# batch [90],Epoch going [0], Loss: 131.44302380084991
# batch [91],Epoch going [0], Loss: 132.70889556407928
# batch [92],Epoch going [0], Loss: 134.02919971942902
# batch [93],Epoch going [0], Loss: 135.2633376121521
# batch [94],Epoch going [0], Loss: 136.6721076965332
# batch [95],Epoch going [0], Loss: 138.03528606891632
# batch [96],Epoch going [0], Loss: 139.44769275188446
# batch [97],Epoch going [0], Loss: 140.86004650592804
# batch [98],Epoch going [0], Loss: 142.2761174440384
# batch [99],Epoch going [0], Loss: 143.64015758037567
# batch [100],Epoch going [0], Loss: 145.04449498653412
# batch [101],Epoch going [0], Loss: 146.3563050031662
# batch [102],Epoch going [0], Loss: 147.62791168689728
# batch [103],Epoch going [0], Loss: 148.953183054924
# batch [104],Epoch going [0], Loss: 150.1923850774765
# batch [105],Epoch going [0], Loss: 151.55179405212402
# batch [106],Epoch going [0], Loss: 152.90108370780945
# batch [107],Epoch going [0], Loss: 154.24849820137024
# batch [108],Epoch going [0], Loss: 155.63387370109558
# batch [109],Epoch going [0], Loss: 156.93505549430847
# batch [110],Epoch going [0], Loss: 158.2327412366867
# batch [111],Epoch going [0], Loss: 159.54925167560577
# batch [112],Epoch going [0], Loss: 160.90851974487305
# batch [113],Epoch going [0], Loss: 162.22415208816528
# batch [114],Epoch going [0], Loss: 163.6177248954773
# batch [115],Epoch going [0], Loss: 164.91581428050995
# batch [116],Epoch going [0], Loss: 166.18965208530426
# batch [117],Epoch going [0], Loss: 167.4738734960556
# batch [118],Epoch going [0], Loss: 168.77277147769928
# batch [119],Epoch going [0], Loss: 170.11134612560272
# batch [120],Epoch going [0], Loss: 171.4429907798767
# batch [121],Epoch going [0], Loss: 172.77954077720642
# batch [122],Epoch going [0], Loss: 174.0735580921173
# batch [123],Epoch going [0], Loss: 175.40307235717773
# batch [124],Epoch going [0], Loss: 176.75687551498413
# batch [125],Epoch going [0], Loss: 178.09826385974884
# batch [126],Epoch going [0], Loss: 179.4055619239807
# batch [127],Epoch going [0], Loss: 180.75240170955658
# batch [128],Epoch going [0], Loss: 182.05263793468475
# batch [129],Epoch going [0], Loss: 183.35778176784515
# batch [130],Epoch going [0], Loss: 184.80731809139252
# batch [131],Epoch going [0], Loss: 186.24720239639282
# batch [132],Epoch going [0], Loss: 187.55405855178833
# batch [133],Epoch going [0], Loss: 188.93365156650543
# batch [134],Epoch going [0], Loss: 190.24382197856903
# batch [135],Epoch going [0], Loss: 191.52297687530518
# batch [136],Epoch going [0], Loss: 192.88738131523132
# batch [137],Epoch going [0], Loss: 194.19825839996338
# batch [138],Epoch going [0], Loss: 195.62041544914246
# batch [139],Epoch going [0], Loss: 196.9783697128296
# batch [140],Epoch going [0], Loss: 198.21128404140472
# batch [141],Epoch going [0], Loss: 199.52086544036865
# batch [142],Epoch going [0], Loss: 200.79607796669006
# batch [143],Epoch going [0], Loss: 202.12065029144287
# batch [144],Epoch going [0], Loss: 203.4197976589203
# batch [145],Epoch going [0], Loss: 204.75759172439575
# batch [146],Epoch going [0], Loss: 206.02610063552856
# batch [147],Epoch going [0], Loss: 207.29049372673035
# batch [148],Epoch going [0], Loss: 208.5861029624939
# batch [149],Epoch going [0], Loss: 209.94051134586334
# batch [150],Epoch going [0], Loss: 211.32587909698486
# batch [151],Epoch going [0], Loss: 212.62591767311096
# batch [152],Epoch going [0], Loss: 213.93083906173706
# batch [153],Epoch going [0], Loss: 215.1889889240265
# batch [154],Epoch going [0], Loss: 216.4612774848938
# batch [155],Epoch going [0], Loss: 217.7388210296631
# batch [156],Epoch going [0], Loss: 219.033304810524
# batch [157],Epoch going [0], Loss: 220.3564409017563
# batch [158],Epoch going [0], Loss: 221.71172523498535
# batch [159],Epoch going [0], Loss: 222.96244072914124
# batch [160],Epoch going [0], Loss: 224.28594779968262
# batch [161],Epoch going [0], Loss: 225.58436703681946
# batch [162],Epoch going [0], Loss: 226.82147812843323
# batch [163],Epoch going [0], Loss: 228.13538539409637
# batch [164],Epoch going [0], Loss: 229.43448889255524
# batch [165],Epoch going [0], Loss: 230.7023330926895
# batch [166],Epoch going [0], Loss: 231.98147785663605
# batch [167],Epoch going [0], Loss: 233.30900263786316
# batch [168],Epoch going [0], Loss: 234.6476548910141
# batch [169],Epoch going [0], Loss: 235.90362930297852
# batch [170],Epoch going [0], Loss: 237.17336106300354
# batch [171],Epoch going [0], Loss: 238.4397497177124
# batch [172],Epoch going [0], Loss: 239.7031273841858
# batch [173],Epoch going [0], Loss: 241.0186026096344
# batch [174],Epoch going [0], Loss: 242.34527850151062
# batch [175],Epoch going [0], Loss: 243.62888288497925
# batch [176],Epoch going [0], Loss: 244.85732781887054
# batch [177],Epoch going [0], Loss: 246.12250804901123
# batch [178],Epoch going [0], Loss: 247.40611279010773
# batch [179],Epoch going [0], Loss: 248.70319509506226
# batch [180],Epoch going [0], Loss: 249.9673240184784
# batch [181],Epoch going [0], Loss: 251.25516283512115
# batch [182],Epoch going [0], Loss: 252.61237752437592
# batch [183],Epoch going [0], Loss: 253.85160863399506
# batch [184],Epoch going [0], Loss: 255.113499045372
# batch [185],Epoch going [0], Loss: 256.2862013578415
# batch [186],Epoch going [0], Loss: 257.53649175167084
# batch [187],Epoch going [0], Loss: 258.78454661369324
# batch [188],Epoch going [0], Loss: 260.10283744335175
# batch [189],Epoch going [0], Loss: 261.34493148326874
# batch [190],Epoch going [0], Loss: 262.6869806051254
# batch [191],Epoch going [0], Loss: 263.89585733413696
# batch [192],Epoch going [0], Loss: 265.1625076532364
# batch [193],Epoch going [0], Loss: 266.4960734844208
# batch [194],Epoch going [0], Loss: 267.83097887039185
# batch [195],Epoch going [0], Loss: 269.09194099903107
# batch [196],Epoch going [0], Loss: 270.4109288454056
# batch [197],Epoch going [0], Loss: 271.67819941043854
# batch [198],Epoch going [0], Loss: 272.9536324739456
# batch [199],Epoch going [0], Loss: 274.1937880516052
# batch [200],Epoch going [0], Loss: 275.53278148174286
# batch [201],Epoch going [0], Loss: 276.7881498336792
# batch [202],Epoch going [0], Loss: 278.13492119312286
# batch [203],Epoch going [0], Loss: 279.39728915691376
# batch [204],Epoch going [0], Loss: 280.6209799051285
# batch [205],Epoch going [0], Loss: 281.8581873178482
# batch [206],Epoch going [0], Loss: 283.1878924369812
# batch [207],Epoch going [0], Loss: 284.4260641336441
# batch [208],Epoch going [0], Loss: 285.7550970315933
# batch [209],Epoch going [0], Loss: 286.9652123451233
# batch [210],Epoch going [0], Loss: 288.2631981372833
# batch [211],Epoch going [0], Loss: 289.46647000312805
# batch [212],Epoch going [0], Loss: 290.74041724205017
# batch [213],Epoch going [0], Loss: 292.0774666070938
# batch [214],Epoch going [0], Loss: 293.339239358902
# batch [215],Epoch going [0], Loss: 294.6494998931885
# batch [216],Epoch going [0], Loss: 295.8001780509949
# batch [217],Epoch going [0], Loss: 297.0901143550873
# batch [218],Epoch going [0], Loss: 298.30938386917114
# batch [219],Epoch going [0], Loss: 299.5405623912811
# batch [220],Epoch going [0], Loss: 300.80433785915375
# batch [221],Epoch going [0], Loss: 302.0765161514282
# batch [222],Epoch going [0], Loss: 303.3205111026764
# batch [223],Epoch going [0], Loss: 304.56260919570923
# batch [224],Epoch going [0], Loss: 305.8428518772125
# batch [225],Epoch going [0], Loss: 307.0422428846359
# batch [226],Epoch going [0], Loss: 308.31318962574005
# batch [227],Epoch going [0], Loss: 309.55168521404266
# batch [228],Epoch going [0], Loss: 310.80298686027527
# batch [229],Epoch going [0], Loss: 312.10304844379425
# batch [230],Epoch going [0], Loss: 313.31467163562775
# batch [231],Epoch going [0], Loss: 314.5708364248276
# batch [232],Epoch going [0], Loss: 315.8450893163681
# batch [233],Epoch going [0], Loss: 317.18216276168823
# batch [234],Epoch going [0], Loss: 318.43828797340393
# batch [235],Epoch going [0], Loss: 319.6647732257843
# batch [236],Epoch going [0], Loss: 321.00921726226807
# batch [237],Epoch going [0], Loss: 322.2925343513489
# batch [238],Epoch going [0], Loss: 323.6223602294922
# batch [239],Epoch going [0], Loss: 324.85489869117737
# batch [240],Epoch going [0], Loss: 326.03639006614685
# batch [241],Epoch going [0], Loss: 327.2862946987152
# batch [242],Epoch going [0], Loss: 328.50531101226807
# batch [243],Epoch going [0], Loss: 329.6953239440918
# batch [244],Epoch going [0], Loss: 330.8868626356125
# batch [245],Epoch going [0], Loss: 332.1019107103348
# batch [246],Epoch going [0], Loss: 333.2812489271164
# batch [247],Epoch going [0], Loss: 334.50801277160645
# batch [248],Epoch going [0], Loss: 335.7913852930069
# batch [249],Epoch going [0], Loss: 337.01300847530365
# batch [250],Epoch going [0], Loss: 338.3471977710724
# batch [251],Epoch going [0], Loss: 339.53932070732117
# batch [252],Epoch going [0], Loss: 340.79580783843994
# batch [253],Epoch going [0], Loss: 341.97459387779236
# batch [254],Epoch going [0], Loss: 343.1642940044403
# batch [255],Epoch going [0], Loss: 344.3687410354614
# batch [256],Epoch going [0], Loss: 345.5807110071182
# batch [257],Epoch going [0], Loss: 346.82691299915314
# batch [258],Epoch going [0], Loss: 348.07474195957184
# batch [259],Epoch going [0], Loss: 349.29640090465546
# batch [260],Epoch going [0], Loss: 350.5293411016464
# batch [261],Epoch going [0], Loss: 351.8277430534363
# batch [262],Epoch going [0], Loss: 353.03419840335846
# batch [263],Epoch going [0], Loss: 354.30209398269653
# batch [264],Epoch going [0], Loss: 355.55720925331116
# batch [265],Epoch going [0], Loss: 356.7290884256363
# batch [266],Epoch going [0], Loss: 358.0823118686676
# batch [267],Epoch going [0], Loss: 359.31235337257385
# batch [268],Epoch going [0], Loss: 360.6237337589264
# batch [269],Epoch going [0], Loss: 361.84760200977325
# batch [270],Epoch going [0], Loss: 363.07402539253235
# batch [271],Epoch going [0], Loss: 364.36085975170135
# batch [272],Epoch going [0], Loss: 365.59840857982635
# batch [273],Epoch going [0], Loss: 366.96818947792053
# batch [274],Epoch going [0], Loss: 368.26918268203735
# batch [275],Epoch going [0], Loss: 369.5510802268982
# batch [276],Epoch going [0], Loss: 370.8159593343735
# batch [277],Epoch going [0], Loss: 372.0549600124359
# batch [278],Epoch going [0], Loss: 373.32191574573517
# batch [279],Epoch going [0], Loss: 374.53438556194305
# batch [280],Epoch going [0], Loss: 375.77717757225037
# batch [281],Epoch going [0], Loss: 377.0569496154785
# batch [282],Epoch going [0], Loss: 378.34243273735046
# batch [283],Epoch going [0], Loss: 379.59128844738007
# batch [284],Epoch going [0], Loss: 380.8670424222946
# batch [285],Epoch going [0], Loss: 382.1401629447937
# batch [286],Epoch going [0], Loss: 383.3695285320282
# batch [287],Epoch going [0], Loss: 384.5760097503662
# batch [288],Epoch going [0], Loss: 385.8046073913574
# batch [289],Epoch going [0], Loss: 387.10189282894135
# batch [290],Epoch going [0], Loss: 388.3106459379196
# batch [291],Epoch going [0], Loss: 389.6011663675308
# batch [292],Epoch going [0], Loss: 390.8297288417816
# batch [293],Epoch going [0], Loss: 392.0827008485794
# batch [294],Epoch going [0], Loss: 393.3148959875107
# batch [295],Epoch going [0], Loss: 394.60189187526703
# batch [296],Epoch going [0], Loss: 395.84196150302887
# batch [297],Epoch going [0], Loss: 397.1138793230057
# batch [298],Epoch going [0], Loss: 398.29501950740814
# batch [299],Epoch going [0], Loss: 399.54330110549927
# batch [300],Epoch going [0], Loss: 400.7774426937103
# batch [301],Epoch going [0], Loss: 402.1111960411072
# batch [302],Epoch going [0], Loss: 403.3622841835022
# batch [303],Epoch going [0], Loss: 404.58893394470215
# batch [304],Epoch going [0], Loss: 405.7956621646881
# batch [305],Epoch going [0], Loss: 407.07218980789185
# batch [306],Epoch going [0], Loss: 408.28345131874084
# batch [307],Epoch going [0], Loss: 409.5050917863846
# batch [308],Epoch going [0], Loss: 410.7812877893448
# batch [309],Epoch going [0], Loss: 412.0305005311966
# batch [310],Epoch going [0], Loss: 413.3130487203598
# batch [311],Epoch going [0], Loss: 414.53424870967865
# batch [312],Epoch going [0], Loss: 415.7712275981903
# batch [313],Epoch going [0], Loss: 417.06560349464417
# batch [314],Epoch going [0], Loss: 418.2765779495239
# batch [315],Epoch going [0], Loss: 419.6410219669342
# batch [316],Epoch going [0], Loss: 420.83822894096375
# batch [317],Epoch going [0], Loss: 422.07413959503174
# batch [318],Epoch going [0], Loss: 423.25251817703247
# batch [319],Epoch going [0], Loss: 424.4714354276657
# batch [320],Epoch going [0], Loss: 425.7014809846878
# batch [321],Epoch going [0], Loss: 427.01832127571106
# batch [322],Epoch going [0], Loss: 428.24590027332306
# batch [323],Epoch going [0], Loss: 429.50740444660187
# batch [324],Epoch going [0], Loss: 430.7780547142029
# batch [325],Epoch going [0], Loss: 431.95526909828186
# batch [326],Epoch going [0], Loss: 433.12349689006805
# batch [327],Epoch going [0], Loss: 434.4187345504761
# batch [328],Epoch going [0], Loss: 435.73972725868225
# batch [329],Epoch going [0], Loss: 436.97262239456177
# batch [330],Epoch going [0], Loss: 438.205543756485
# batch [331],Epoch going [0], Loss: 439.4492236375809
# batch [332],Epoch going [0], Loss: 440.7122904062271
# batch [333],Epoch going [0], Loss: 442.0045644044876
# batch [334],Epoch going [0], Loss: 443.21381318569183
# batch [335],Epoch going [0], Loss: 444.5708017349243
# batch [336],Epoch going [0], Loss: 445.89817357063293
# batch [337],Epoch going [0], Loss: 447.2040936946869
# batch [338],Epoch going [0], Loss: 448.45486295223236
# batch [339],Epoch going [0], Loss: 449.73169481754303
# batch [340],Epoch going [0], Loss: 451.03095757961273
# batch [341],Epoch going [0], Loss: 452.2765647172928
# batch [342],Epoch going [0], Loss: 453.474124789238
# batch [343],Epoch going [0], Loss: 454.71443247795105
# batch [344],Epoch going [0], Loss: 455.92780661582947
# batch [345],Epoch going [0], Loss: 457.17707443237305
# batch [346],Epoch going [0], Loss: 458.4482614994049
# batch [347],Epoch going [0], Loss: 459.61928164958954
# batch [348],Epoch going [0], Loss: 460.8172116279602
# batch [349],Epoch going [0], Loss: 462.0321663618088
# batch [350],Epoch going [0], Loss: 463.26005923748016
# batch [351],Epoch going [0], Loss: 464.5023467540741
# batch [352],Epoch going [0], Loss: 465.6786276102066
# batch [353],Epoch going [0], Loss: 466.9014836549759
# batch [354],Epoch going [0], Loss: 468.0986112356186
# batch [355],Epoch going [0], Loss: 469.3183332681656
# batch [356],Epoch going [0], Loss: 470.60407316684723
# batch [357],Epoch going [0], Loss: 471.81937634944916
# batch [358],Epoch going [0], Loss: 473.0808650255203
# batch [359],Epoch going [0], Loss: 474.4269244670868
# batch [360],Epoch going [0], Loss: 475.64863872528076
# batch [361],Epoch going [0], Loss: 476.8264993429184
# batch [362],Epoch going [0], Loss: 478.02872252464294
# batch [363],Epoch going [0], Loss: 479.3186305761337
# batch [364],Epoch going [0], Loss: 480.54071021080017
# batch [365],Epoch going [0], Loss: 481.73799681663513
# batch [366],Epoch going [0], Loss: 482.91814827919006
# batch [367],Epoch going [0], Loss: 484.1068581342697
# batch [368],Epoch going [0], Loss: 485.3861976861954
# batch [369],Epoch going [0], Loss: 486.6243739128113
# batch [370],Epoch going [0], Loss: 487.81314158439636
# batch [371],Epoch going [0], Loss: 488.99228835105896
# batch [372],Epoch going [0], Loss: 490.29948377609253
# batch [373],Epoch going [0], Loss: 491.5388071537018
# batch [374],Epoch going [0], Loss: 492.847704410553
# batch [375],Epoch going [0], Loss: 494.05837643146515
# batch [376],Epoch going [0], Loss: 495.32796359062195
# batch [377],Epoch going [0], Loss: 496.5838963985443
# batch [378],Epoch going [0], Loss: 497.80938029289246
# batch [379],Epoch going [0], Loss: 499.0038894414902
# batch [380],Epoch going [0], Loss: 500.1895977258682
# batch [381],Epoch going [0], Loss: 501.4606603384018
# batch [382],Epoch going [0], Loss: 502.7405334711075
# batch [383],Epoch going [0], Loss: 503.9451177120209
# batch [384],Epoch going [0], Loss: 505.1651430130005
# batch [385],Epoch going [0], Loss: 506.3535889387131
# batch [386],Epoch going [0], Loss: 507.60220205783844
# batch [387],Epoch going [0], Loss: 508.8487924337387
# batch [388],Epoch going [0], Loss: 510.0474613904953
# batch [389],Epoch going [0], Loss: 511.32191479206085
# batch [390],Epoch going [0], Loss: 512.5175873041153
# batch [391],Epoch going [0], Loss: 513.8086003065109
# batch [392],Epoch going [0], Loss: 515.0294955968857
# batch [393],Epoch going [0], Loss: 516.2609701156616
# batch [394],Epoch going [0], Loss: 517.4707083702087
# batch [395],Epoch going [0], Loss: 518.7222585678101
# batch [396],Epoch going [0], Loss: 519.9803155660629
# batch [397],Epoch going [0], Loss: 521.2005623579025
# batch [398],Epoch going [0], Loss: 522.3754967451096
# batch [399],Epoch going [0], Loss: 523.6031144857407
# batch [400],Epoch going [0], Loss: 524.9032890796661
# batch [401],Epoch going [0], Loss: 526.0734013319016
# batch [402],Epoch going [0], Loss: 527.348291516304
# batch [403],Epoch going [0], Loss: 528.6520839929581
# batch [404],Epoch going [0], Loss: 529.8730676174164
# batch [405],Epoch going [0], Loss: 531.1317870616913
# batch [406],Epoch going [0], Loss: 532.314421415329
# batch [407],Epoch going [0], Loss: 533.5269904136658
# batch [408],Epoch going [0], Loss: 534.8080135583878
# batch [409],Epoch going [0], Loss: 536.0073192119598
# batch [410],Epoch going [0], Loss: 537.3045921325684
# batch [411],Epoch going [0], Loss: 538.4595010280609
# batch [412],Epoch going [0], Loss: 539.7733982801437
# batch [413],Epoch going [0], Loss: 541.0005522966385
# batch [414],Epoch going [0], Loss: 542.2011629343033
# batch [415],Epoch going [0], Loss: 543.4747174978256
# batch [416],Epoch going [0], Loss: 544.7447816133499
# batch [417],Epoch going [0], Loss: 546.002645611763
# batch [418],Epoch going [0], Loss: 547.2743192911148
# batch [419],Epoch going [0], Loss: 548.539259314537
# batch [420],Epoch going [0], Loss: 549.7180777788162
# batch [421],Epoch going [0], Loss: 550.9782282114029
# batch [422],Epoch going [0], Loss: 552.2225288152695
# batch [423],Epoch going [0], Loss: 553.4180142879486
# batch [424],Epoch going [0], Loss: 554.6189278364182
# batch [425],Epoch going [0], Loss: 555.8345460891724
# batch [426],Epoch going [0], Loss: 557.083794593811
# batch [427],Epoch going [0], Loss: 558.3266553878784
# batch [428],Epoch going [0], Loss: 559.5900293588638
# batch [429],Epoch going [0], Loss: 560.8012830018997
# batch [430],Epoch going [0], Loss: 562.029443860054
# batch [431],Epoch going [0], Loss: 563.1957043409348
# batch [432],Epoch going [0], Loss: 564.4213114976883
# batch [433],Epoch going [0], Loss: 565.659792304039
# batch [434],Epoch going [0], Loss: 566.8427529335022
# batch [435],Epoch going [0], Loss: 568.0862560272217
# batch [436],Epoch going [0], Loss: 569.2679011821747
# batch [437],Epoch going [0], Loss: 570.5135215520859
# batch [438],Epoch going [0], Loss: 571.7932231426239
# batch [439],Epoch going [0], Loss: 573.0085333585739
# batch [440],Epoch going [0], Loss: 574.1933146715164
# batch [441],Epoch going [0], Loss: 575.4134050607681
# batch [442],Epoch going [0], Loss: 576.5723254680634
# batch [443],Epoch going [0], Loss: 577.8327659368515
# batch [444],Epoch going [0], Loss: 579.031347155571
# batch [445],Epoch going [0], Loss: 580.2121495008469
# batch [446],Epoch going [0], Loss: 581.4393291473389
# batch [447],Epoch going [0], Loss: 582.6841864585876
# batch [448],Epoch going [0], Loss: 583.8885171413422
# batch [449],Epoch going [0], Loss: 585.1822910308838
# batch [450],Epoch going [0], Loss: 586.4112448692322
# batch [451],Epoch going [0], Loss: 587.5608944892883
# batch [452],Epoch going [0], Loss: 588.7608281373978
# batch [453],Epoch going [0], Loss: 590.0180175304413
# batch [454],Epoch going [0], Loss: 591.2354747056961
# batch [455],Epoch going [0], Loss: 592.4851220846176
# batch [456],Epoch going [0], Loss: 593.6956757307053
# batch [457],Epoch going [0], Loss: 594.9420082569122
# batch [458],Epoch going [0], Loss: 596.192743897438
# batch [459],Epoch going [0], Loss: 597.3584605455399
# batch [460],Epoch going [0], Loss: 598.6922394037247
# batch [461],Epoch going [0], Loss: 599.9000478982925
# batch [462],Epoch going [0], Loss: 601.1540020704269
# batch [463],Epoch going [0], Loss: 602.4398649930954
# batch [464],Epoch going [0], Loss: 603.6265395879745
# batch [465],Epoch going [0], Loss: 604.8775471448898
# batch [466],Epoch going [0], Loss: 606.1051481962204
# batch [467],Epoch going [0], Loss: 607.2524048089981
# batch [468],Epoch going [0], Loss: 608.4948137998581
# batch [469],Epoch going [0], Loss: 609.7094584703445
# batch [470],Epoch going [0], Loss: 610.9524306058884
# batch [471],Epoch going [0], Loss: 612.2360793352127
# batch [472],Epoch going [0], Loss: 613.4564205408096
# batch [473],Epoch going [0], Loss: 614.7297774553299
# batch [474],Epoch going [0], Loss: 616.0084812641144
# batch [475],Epoch going [0], Loss: 617.1618177890778
# batch [476],Epoch going [0], Loss: 618.3689337968826
# batch [477],Epoch going [0], Loss: 619.6328983306885
# batch [478],Epoch going [0], Loss: 620.8249230384827
# batch [479],Epoch going [0], Loss: 622.0527381896973
# batch [480],Epoch going [0], Loss: 623.3815320730209
# batch [481],Epoch going [0], Loss: 624.6577957868576
# batch [482],Epoch going [0], Loss: 625.8681503534317
# batch [483],Epoch going [0], Loss: 627.0251187086105
# batch [484],Epoch going [0], Loss: 628.172464966774
# batch [485],Epoch going [0], Loss: 629.4303395748138
# batch [486],Epoch going [0], Loss: 630.6932444572449
# batch [487],Epoch going [0], Loss: 631.952641248703
# batch [488],Epoch going [0], Loss: 633.1001136302948
# batch [489],Epoch going [0], Loss: 634.2955615520477
# batch [490],Epoch going [0], Loss: 635.478759765625
# batch [491],Epoch going [0], Loss: 636.7308740615845
# batch [492],Epoch going [0], Loss: 637.9290636777878
# batch [493],Epoch going [0], Loss: 639.1706503629684
# batch [494],Epoch going [0], Loss: 640.469456911087
# batch [495],Epoch going [0], Loss: 641.6457916498184
# batch [496],Epoch going [0], Loss: 642.9079276323318
# batch [497],Epoch going [0], Loss: 644.1141880750656
# batch [498],Epoch going [0], Loss: 645.3663803339005
# batch [499],Epoch going [0], Loss: 646.5521570444107
# batch [500],Epoch going [0], Loss: 647.773109793663
# batch [501],Epoch going [0], Loss: 648.9693200588226
# batch [502],Epoch going [0], Loss: 650.3127897977829
# batch [503],Epoch going [0], Loss: 651.5582826137543
# batch [504],Epoch going [0], Loss: 652.8103802204132
# batch [505],Epoch going [0], Loss: 654.0159661769867
# batch [506],Epoch going [0], Loss: 655.2628563642502
# batch [507],Epoch going [0], Loss: 656.4783024787903
# batch [508],Epoch going [0], Loss: 657.6666928529739
# batch [509],Epoch going [0], Loss: 658.8597835302353
# batch [510],Epoch going [0], Loss: 660.0686579942703
# batch [511],Epoch going [0], Loss: 661.237046122551
# batch [512],Epoch going [0], Loss: 662.3925117254257
# batch [513],Epoch going [0], Loss: 663.6287888288498
# batch [514],Epoch going [0], Loss: 664.8609856367111
# batch [515],Epoch going [0], Loss: 666.0377177000046
# batch [516],Epoch going [0], Loss: 667.2888711690903
# batch [517],Epoch going [0], Loss: 668.5348610877991
# batch [518],Epoch going [0], Loss: 669.7353805303574
# batch [519],Epoch going [0], Loss: 670.979469537735
# batch [520],Epoch going [0], Loss: 672.2034270763397
# batch [521],Epoch going [0], Loss: 673.4656343460083
# batch [522],Epoch going [0], Loss: 674.7274407148361
# batch [523],Epoch going [0], Loss: 675.9364928007126
# batch [524],Epoch going [0], Loss: 677.2137089967728
# batch [525],Epoch going [0], Loss: 678.3854964971542
# batch [526],Epoch going [0], Loss: 679.5877007246017
# batch [527],Epoch going [0], Loss: 680.8773540258408
# batch [528],Epoch going [0], Loss: 682.0894256830215
# batch [529],Epoch going [0], Loss: 683.2604345083237
# batch [530],Epoch going [0], Loss: 684.5073879957199
# batch [531],Epoch going [0], Loss: 685.7758209705353
# batch [532],Epoch going [0], Loss: 686.935452580452
# batch [533],Epoch going [0], Loss: 688.1312032938004
# batch [534],Epoch going [0], Loss: 689.2749963998795
# batch [535],Epoch going [0], Loss: 690.462416768074
# batch [536],Epoch going [0], Loss: 691.6774628162384
# batch [537],Epoch going [0], Loss: 692.9077117443085
# batch [538],Epoch going [0], Loss: 694.1543335914612
# batch [539],Epoch going [0], Loss: 695.4033499956131
# batch [540],Epoch going [0], Loss: 696.6305783987045
# batch [541],Epoch going [0], Loss: 697.8207935094833
# batch [542],Epoch going [0], Loss: 699.0504821538925
# batch [543],Epoch going [0], Loss: 700.2253761291504
# batch [544],Epoch going [0], Loss: 701.4291189908981
# batch [545],Epoch going [0], Loss: 702.7113920450211
# batch [546],Epoch going [0], Loss: 703.9284363985062
# batch [547],Epoch going [0], Loss: 705.1467057466507
# batch [548],Epoch going [0], Loss: 706.3534486293793
# batch [549],Epoch going [0], Loss: 707.5896011590958
# batch [550],Epoch going [0], Loss: 708.7943365573883
# batch [551],Epoch going [0], Loss: 709.992429971695
# batch [552],Epoch going [0], Loss: 711.1702246665955
# batch [553],Epoch going [0], Loss: 712.4118033647537
# batch [554],Epoch going [0], Loss: 713.6041588783264
# batch [555],Epoch going [0], Loss: 714.829537153244
# batch [556],Epoch going [0], Loss: 715.9811195135117
# batch [557],Epoch going [0], Loss: 717.2211319208145
# batch [558],Epoch going [0], Loss: 718.4724327325821
# batch [559],Epoch going [0], Loss: 719.6608160734177
# batch [560],Epoch going [0], Loss: 720.8418356180191
# batch [561],Epoch going [0], Loss: 722.0243638753891
# batch [562],Epoch going [0], Loss: 723.3832136392593
# batch [563],Epoch going [0], Loss: 724.6027833223343
# batch [564],Epoch going [0], Loss: 725.7589296102524
# batch [565],Epoch going [0], Loss: 726.9880810976028
# batch [566],Epoch going [0], Loss: 728.2174330949783
# batch [567],Epoch going [0], Loss: 729.4188196659088
# batch [568],Epoch going [0], Loss: 730.6550171375275
# batch [569],Epoch going [0], Loss: 731.932567358017
# batch [570],Epoch going [0], Loss: 733.1846091747284
# batch [571],Epoch going [0], Loss: 734.3489937782288
# batch [572],Epoch going [0], Loss: 735.5475331544876
# batch [573],Epoch going [0], Loss: 736.7574338912964
# batch [574],Epoch going [0], Loss: 737.9864554405212
# batch [575],Epoch going [0], Loss: 739.174985408783
# batch [576],Epoch going [0], Loss: 740.3633065223694
# batch [577],Epoch going [0], Loss: 741.5722541809082
# batch [578],Epoch going [0], Loss: 742.8239960670471
# batch [579],Epoch going [0], Loss: 744.0511717796326
# batch [580],Epoch going [0], Loss: 745.239697098732
# batch [581],Epoch going [0], Loss: 746.5164917707443
# batch [582],Epoch going [0], Loss: 747.7070006132126
# batch [583],Epoch going [0], Loss: 748.9173992872238
# batch [584],Epoch going [0], Loss: 750.1730732917786
# batch [585],Epoch going [0], Loss: 751.3727345466614
# batch [586],Epoch going [0], Loss: 752.5384645462036
# batch [587],Epoch going [0], Loss: 753.7576017379761
# batch [588],Epoch going [0], Loss: 754.9392858743668
# batch [589],Epoch going [0], Loss: 756.1119412183762
# batch [590],Epoch going [0], Loss: 757.3153921365738
# batch [591],Epoch going [0], Loss: 758.5211879014969
# batch [592],Epoch going [0], Loss: 759.7497730255127
# batch [593],Epoch going [0], Loss: 760.9381083250046
# batch [594],Epoch going [0], Loss: 762.1427863836288
# batch [595],Epoch going [0], Loss: 763.367623925209
# batch [596],Epoch going [0], Loss: 764.5862801074982
# batch [597],Epoch going [0], Loss: 765.7546284198761
# batch [598],Epoch going [0], Loss: 766.9596059322357
# batch [599],Epoch going [0], Loss: 768.2380211353302
# batch [600],Epoch going [0], Loss: 769.4461567401886
# batch [601],Epoch going [0], Loss: 770.6556080579758
# batch [602],Epoch going [0], Loss: 771.9179611206055
# batch [603],Epoch going [0], Loss: 773.133134841919
# batch [604],Epoch going [0], Loss: 774.3244234323502
# batch [605],Epoch going [0], Loss: 775.62271463871
# batch [606],Epoch going [0], Loss: 776.7931238412857
# batch [607],Epoch going [0], Loss: 778.020469546318
# batch [608],Epoch going [0], Loss: 779.3167263269424
# batch [609],Epoch going [0], Loss: 780.4792419672012
# batch [610],Epoch going [0], Loss: 781.7346612215042
# batch [611],Epoch going [0], Loss: 782.9780671596527
# batch [612],Epoch going [0], Loss: 784.1865718364716
# batch [613],Epoch going [0], Loss: 785.305935382843
# batch [614],Epoch going [0], Loss: 786.5182440280914
# batch [615],Epoch going [0], Loss: 787.6889189481735
# batch [616],Epoch going [0], Loss: 788.8754109144211
# batch [617],Epoch going [0], Loss: 790.0876806974411
# batch [618],Epoch going [0], Loss: 791.278973698616
# batch [619],Epoch going [0], Loss: 792.4682027101517
# batch [620],Epoch going [0], Loss: 793.6008573770523
# batch [621],Epoch going [0], Loss: 794.8601496219635
# batch [622],Epoch going [0], Loss: 796.1742119789124
# batch [623],Epoch going [0], Loss: 797.40509557724
# batch [624],Epoch going [0], Loss: 798.5589916706085
# batch [625],Epoch going [0], Loss: 799.7913049459457
# batch [626],Epoch going [0], Loss: 800.9769328832626
# batch [627],Epoch going [0], Loss: 802.1213978528976
# batch [628],Epoch going [0], Loss: 803.3406558036804
# batch [629],Epoch going [0], Loss: 804.4990866184235
# batch [630],Epoch going [0], Loss: 805.7542606592178
# batch [631],Epoch going [0], Loss: 806.9541879892349
# batch [632],Epoch going [0], Loss: 808.1612924337387
# batch [633],Epoch going [0], Loss: 809.389234662056
# batch [634],Epoch going [0], Loss: 810.6094094514847
# batch [635],Epoch going [0], Loss: 811.849218249321
# batch [636],Epoch going [0], Loss: 813.1373142004013
# batch [637],Epoch going [0], Loss: 814.3651239871979
# batch [638],Epoch going [0], Loss: 815.5365146398544
# batch [639],Epoch going [0], Loss: 816.736398100853
# batch [640],Epoch going [0], Loss: 817.928502202034
# batch [641],Epoch going [0], Loss: 819.1436330080032
# batch [642],Epoch going [0], Loss: 820.3085962533951
# batch [643],Epoch going [0], Loss: 821.5084518194199
# batch [644],Epoch going [0], Loss: 822.688992857933
# batch [645],Epoch going [0], Loss: 823.9593895673752
# batch [646],Epoch going [0], Loss: 825.1028188467026
# batch [647],Epoch going [0], Loss: 826.3763496875763
# batch [648],Epoch going [0], Loss: 827.561581492424
# batch [649],Epoch going [0], Loss: 828.826407790184
# batch [650],Epoch going [0], Loss: 830.0725481510162
# batch [651],Epoch going [0], Loss: 831.2971332073212
# batch [652],Epoch going [0], Loss: 832.5150322914124
# batch [653],Epoch going [0], Loss: 833.7756378650665
# batch [654],Epoch going [0], Loss: 835.0038633346558
# batch [655],Epoch going [0], Loss: 836.2229574918747
# batch [656],Epoch going [0], Loss: 837.4768227338791
# batch [657],Epoch going [0], Loss: 838.6828957796097
# batch [658],Epoch going [0], Loss: 839.9050936698914
# batch [659],Epoch going [0], Loss: 841.1599720716476
# batch [660],Epoch going [0], Loss: 842.4228178262711
# batch [661],Epoch going [0], Loss: 843.6647840738297
# batch [662],Epoch going [0], Loss: 844.8755365610123
# batch [663],Epoch going [0], Loss: 846.070170044899
# batch [664],Epoch going [0], Loss: 847.2931344509125
# batch [665],Epoch going [0], Loss: 848.5440434217453
# batch [666],Epoch going [0], Loss: 849.7961715459824
# batch [667],Epoch going [0], Loss: 850.9725135564804
# batch [668],Epoch going [0], Loss: 852.1899696588516
# batch [669],Epoch going [0], Loss: 853.3886400461197
# batch [670],Epoch going [0], Loss: 854.566123008728
# batch [671],Epoch going [0], Loss: 855.7012133598328
# batch [672],Epoch going [0], Loss: 856.9636729955673
# batch [673],Epoch going [0], Loss: 858.2584331035614
# batch [674],Epoch going [0], Loss: 859.4762020111084
# batch [675],Epoch going [0], Loss: 860.6327992677689
# batch [676],Epoch going [0], Loss: 861.8354985713959
# batch [677],Epoch going [0], Loss: 863.0701824426651
# batch [678],Epoch going [0], Loss: 864.2001006603241
# batch [679],Epoch going [0], Loss: 865.468093752861
# batch [680],Epoch going [0], Loss: 866.6205285787582
# batch [681],Epoch going [0], Loss: 867.8089331388474
# batch [682],Epoch going [0], Loss: 868.9542909860611
# batch [683],Epoch going [0], Loss: 870.1565970182419
# batch [684],Epoch going [0], Loss: 871.513652920723
# batch [685],Epoch going [0], Loss: 872.6534799337387
# batch [686],Epoch going [0], Loss: 873.8945931196213
# batch [687],Epoch going [0], Loss: 875.1078283786774
# batch [688],Epoch going [0], Loss: 876.322695016861
# batch [689],Epoch going [0], Loss: 877.4900286197662
# batch [690],Epoch going [0], Loss: 878.6682958602905
# batch [691],Epoch going [0], Loss: 879.8111761808395
# batch [692],Epoch going [0], Loss: 881.050816655159
# batch [693],Epoch going [0], Loss: 882.2532793283463
# batch [694],Epoch going [0], Loss: 883.4051767587662
# batch [695],Epoch going [0], Loss: 884.60171854496
# batch [696],Epoch going [0], Loss: 885.8239232301712
# batch [697],Epoch going [0], Loss: 887.0382741689682
# batch [698],Epoch going [0], Loss: 888.3029509782791
# batch [699],Epoch going [0], Loss: 889.5317704677582
# batch [700],Epoch going [0], Loss: 890.7730354070663
# batch [701],Epoch going [0], Loss: 892.0017153024673
# batch [702],Epoch going [0], Loss: 893.1984707117081
# batch [703],Epoch going [0], Loss: 894.4145336151123
# batch [704],Epoch going [0], Loss: 895.6718633174896
# batch [705],Epoch going [0], Loss: 896.9300907850266
# batch [706],Epoch going [0], Loss: 898.128223657608
# batch [707],Epoch going [0], Loss: 899.390302658081
# batch [708],Epoch going [0], Loss: 900.610258102417
# batch [709],Epoch going [0], Loss: 901.79359126091
# batch [710],Epoch going [0], Loss: 902.9094390869141
# batch [711],Epoch going [0], Loss: 904.1264392137527
# batch [712],Epoch going [0], Loss: 905.3651517629623
# batch [713],Epoch going [0], Loss: 906.6089998483658
# batch [714],Epoch going [0], Loss: 907.9189788103104
# batch [715],Epoch going [0], Loss: 909.134757399559
# batch [716],Epoch going [0], Loss: 910.3374520540237
# batch [717],Epoch going [0], Loss: 911.5918720960617
# batch [718],Epoch going [0], Loss: 912.7805304527283
# batch [719],Epoch going [0], Loss: 914.0051066875458
# batch [720],Epoch going [0], Loss: 915.2232028245926
# batch [721],Epoch going [0], Loss: 916.3951963186264
# batch [722],Epoch going [0], Loss: 917.5924592018127
# batch [723],Epoch going [0], Loss: 918.7886662483215
# batch [724],Epoch going [0], Loss: 920.0070762634277
# batch [725],Epoch going [0], Loss: 921.1895623207092
# batch [726],Epoch going [0], Loss: 922.3846855163574
# batch [727],Epoch going [0], Loss: 923.5693798065186
# batch [728],Epoch going [0], Loss: 924.7273205518723
# batch [729],Epoch going [0], Loss: 925.9743049144745
# batch [730],Epoch going [0], Loss: 927.1975736618042
# batch [731],Epoch going [0], Loss: 928.3488473892212
# batch [732],Epoch going [0], Loss: 929.5298182964325
# batch [733],Epoch going [0], Loss: 930.7405750751495
# batch [734],Epoch going [0], Loss: 931.9738700389862
# batch [735],Epoch going [0], Loss: 933.1478576660156
# batch [736],Epoch going [0], Loss: 934.3284420967102
# batch [737],Epoch going [0], Loss: 935.5731580257416
# batch [738],Epoch going [0], Loss: 936.7555387020111
# batch [739],Epoch going [0], Loss: 937.935040473938
# batch [740],Epoch going [0], Loss: 939.2023849487305
# batch [741],Epoch going [0], Loss: 940.3902626037598
# batch [742],Epoch going [0], Loss: 941.6307852268219
# batch [743],Epoch going [0], Loss: 942.8842544555664
# batch [744],Epoch going [0], Loss: 944.1245710849762
# batch [745],Epoch going [0], Loss: 945.3393659591675
# batch [746],Epoch going [0], Loss: 946.5081549882889
# batch [747],Epoch going [0], Loss: 947.7594246864319
# batch [748],Epoch going [0], Loss: 948.9635493755341
# batch [749],Epoch going [0], Loss: 950.178386092186
# batch [750],Epoch going [0], Loss: 951.431648850441
# batch [751],Epoch going [0], Loss: 952.5951991081238
# batch [752],Epoch going [0], Loss: 953.8081691265106
# batch [753],Epoch going [0], Loss: 955.0096237659454
# batch [754],Epoch going [0], Loss: 956.2042229175568
# batch [755],Epoch going [0], Loss: 957.4042168855667
# batch [756],Epoch going [0], Loss: 958.5636541843414
# batch [757],Epoch going [0], Loss: 959.7786855697632
# batch [758],Epoch going [0], Loss: 960.9775538444519
# batch [759],Epoch going [0], Loss: 962.2110155820847
# batch [760],Epoch going [0], Loss: 963.4447549581528
# batch [761],Epoch going [0], Loss: 964.7045222520828
# batch [762],Epoch going [0], Loss: 965.939915060997
# batch [763],Epoch going [0], Loss: 967.2244334220886
# batch [764],Epoch going [0], Loss: 968.3882217407227
# batch [765],Epoch going [0], Loss: 969.6592085361481
# batch [766],Epoch going [0], Loss: 970.8623473644257
# batch [767],Epoch going [0], Loss: 972.0150674581528
# batch [768],Epoch going [0], Loss: 973.2168008089066
# batch [769],Epoch going [0], Loss: 974.424646615982
# batch [770],Epoch going [0], Loss: 975.6193888187408
# batch [771],Epoch going [0], Loss: 976.8066372871399
# batch [772],Epoch going [0], Loss: 978.0184391736984
# batch [773],Epoch going [0], Loss: 979.2355750799179
# batch [774],Epoch going [0], Loss: 980.3817354440689
# batch [775],Epoch going [0], Loss: 981.5379511117935
# batch [776],Epoch going [0], Loss: 982.7577284574509
# batch [777],Epoch going [0], Loss: 983.9277037382126
# batch [778],Epoch going [0], Loss: 985.1066533327103
# batch [779],Epoch going [0], Loss: 986.3943907022476
# batch [780],Epoch going [0], Loss: 987.5960988998413
# batch [781],Epoch going [0], Loss: 988.8457405567169
# epoch[1/15], Loss: 1.2645
# batch [0],Epoch going [1], Loss: 1.1637203693389893
# batch [1],Epoch going [1], Loss: 2.4252288341522217
# batch [2],Epoch going [1], Loss: 3.6154892444610596
# batch [3],Epoch going [1], Loss: 4.786553382873535
# batch [4],Epoch going [1], Loss: 6.086483716964722
# batch [5],Epoch going [1], Loss: 7.3156126737594604
# batch [6],Epoch going [1], Loss: 8.557891368865967
# batch [7],Epoch going [1], Loss: 9.738947629928589
# batch [8],Epoch going [1], Loss: 10.958017945289612
# batch [9],Epoch going [1], Loss: 12.149223566055298
# batch [10],Epoch going [1], Loss: 13.334604263305664
# batch [11],Epoch going [1], Loss: 14.537580609321594
# batch [12],Epoch going [1], Loss: 15.725995659828186
# batch [13],Epoch going [1], Loss: 16.940998196601868
# batch [14],Epoch going [1], Loss: 18.157586455345154
# batch [15],Epoch going [1], Loss: 19.39149558544159
# batch [16],Epoch going [1], Loss: 20.579153418540955
# batch [17],Epoch going [1], Loss: 21.848841190338135
# batch [18],Epoch going [1], Loss: 23.03976571559906
# batch [19],Epoch going [1], Loss: 24.269957423210144
# batch [20],Epoch going [1], Loss: 25.4440860748291
# batch [21],Epoch going [1], Loss: 26.675422191619873
# batch [22],Epoch going [1], Loss: 27.85910153388977
# batch [23],Epoch going [1], Loss: 29.09756636619568
# batch [24],Epoch going [1], Loss: 30.327348232269287
# batch [25],Epoch going [1], Loss: 31.592443227767944
# batch [26],Epoch going [1], Loss: 32.85581350326538
# batch [27],Epoch going [1], Loss: 34.1264545917511
# batch [28],Epoch going [1], Loss: 35.29196500778198
# batch [29],Epoch going [1], Loss: 36.47041201591492
# batch [30],Epoch going [1], Loss: 37.684380769729614
# batch [31],Epoch going [1], Loss: 38.89384341239929
# batch [32],Epoch going [1], Loss: 40.071130990982056
# batch [33],Epoch going [1], Loss: 41.373159885406494
# batch [34],Epoch going [1], Loss: 42.575347542762756
# batch [35],Epoch going [1], Loss: 43.71476137638092
# batch [36],Epoch going [1], Loss: 44.96895158290863
# batch [37],Epoch going [1], Loss: 46.15992820262909
# batch [38],Epoch going [1], Loss: 47.32897651195526
# batch [39],Epoch going [1], Loss: 48.557743191719055
# batch [40],Epoch going [1], Loss: 49.79639804363251
# batch [41],Epoch going [1], Loss: 50.968417286872864
# batch [42],Epoch going [1], Loss: 52.158281207084656
# batch [43],Epoch going [1], Loss: 53.386709332466125
# batch [44],Epoch going [1], Loss: 54.5617870092392
# batch [45],Epoch going [1], Loss: 55.7904167175293
# batch [46],Epoch going [1], Loss: 56.974031925201416
# batch [47],Epoch going [1], Loss: 58.27063035964966
# batch [48],Epoch going [1], Loss: 59.474414467811584
# batch [49],Epoch going [1], Loss: 60.64051330089569
# batch [50],Epoch going [1], Loss: 61.80687725543976
# batch [51],Epoch going [1], Loss: 63.10895538330078
# batch [52],Epoch going [1], Loss: 64.3484365940094
# batch [53],Epoch going [1], Loss: 65.54672122001648
# batch [54],Epoch going [1], Loss: 66.72978377342224
# batch [55],Epoch going [1], Loss: 67.94965267181396
# batch [56],Epoch going [1], Loss: 69.16032004356384
# batch [57],Epoch going [1], Loss: 70.33275318145752
# batch [58],Epoch going [1], Loss: 71.54580366611481
# batch [59],Epoch going [1], Loss: 72.7182446718216
# batch [60],Epoch going [1], Loss: 73.88868963718414
# batch [61],Epoch going [1], Loss: 75.07138311862946
# batch [62],Epoch going [1], Loss: 76.24797761440277
# batch [63],Epoch going [1], Loss: 77.4646977186203
# batch [64],Epoch going [1], Loss: 78.64621484279633
# batch [65],Epoch going [1], Loss: 79.88146483898163
# batch [66],Epoch going [1], Loss: 81.0757348537445
# batch [67],Epoch going [1], Loss: 82.29571080207825
# batch [68],Epoch going [1], Loss: 83.49733424186707
# batch [69],Epoch going [1], Loss: 84.6633517742157
# batch [70],Epoch going [1], Loss: 85.85610175132751
# batch [71],Epoch going [1], Loss: 86.96566617488861
# batch [72],Epoch going [1], Loss: 88.19565045833588
# batch [73],Epoch going [1], Loss: 89.40336418151855
# batch [74],Epoch going [1], Loss: 90.646075963974
# batch [75],Epoch going [1], Loss: 91.91096544265747
# batch [76],Epoch going [1], Loss: 93.06676840782166
# batch [77],Epoch going [1], Loss: 94.33194780349731
# batch [78],Epoch going [1], Loss: 95.49582183361053
# batch [79],Epoch going [1], Loss: 96.70657551288605
# batch [80],Epoch going [1], Loss: 97.87330162525177
# batch [81],Epoch going [1], Loss: 98.95202457904816
# batch [82],Epoch going [1], Loss: 100.16135251522064
# batch [83],Epoch going [1], Loss: 101.36472296714783
# batch [84],Epoch going [1], Loss: 102.53916049003601
# batch [85],Epoch going [1], Loss: 103.72581839561462
# batch [86],Epoch going [1], Loss: 104.89229440689087
# batch [87],Epoch going [1], Loss: 106.09651017189026
# batch [88],Epoch going [1], Loss: 107.27810859680176
# batch [89],Epoch going [1], Loss: 108.43689572811127
# batch [90],Epoch going [1], Loss: 109.60792243480682
# batch [91],Epoch going [1], Loss: 110.77737951278687
# batch [92],Epoch going [1], Loss: 112.01717448234558
# batch [93],Epoch going [1], Loss: 113.27055764198303
# batch [94],Epoch going [1], Loss: 114.475998878479
# batch [95],Epoch going [1], Loss: 115.68266606330872
# batch [96],Epoch going [1], Loss: 116.88448870182037
# batch [97],Epoch going [1], Loss: 118.10802400112152
# batch [98],Epoch going [1], Loss: 119.34716880321503
# batch [99],Epoch going [1], Loss: 120.60046017169952
# batch [100],Epoch going [1], Loss: 121.77478516101837
# batch [101],Epoch going [1], Loss: 122.93835544586182
# batch [102],Epoch going [1], Loss: 124.0910667181015
# batch [103],Epoch going [1], Loss: 125.26469004154205
# batch [104],Epoch going [1], Loss: 126.50577878952026
# batch [105],Epoch going [1], Loss: 127.74755907058716
# batch [106],Epoch going [1], Loss: 128.93852257728577
# batch [107],Epoch going [1], Loss: 130.11066091060638
# batch [108],Epoch going [1], Loss: 131.24382436275482
# batch [109],Epoch going [1], Loss: 132.4200999736786
# batch [110],Epoch going [1], Loss: 133.65421509742737
# batch [111],Epoch going [1], Loss: 134.91015887260437
# batch [112],Epoch going [1], Loss: 136.10751628875732
# batch [113],Epoch going [1], Loss: 137.33445286750793
# batch [114],Epoch going [1], Loss: 138.60201466083527
# batch [115],Epoch going [1], Loss: 139.76813352108002
# batch [116],Epoch going [1], Loss: 140.99892485141754
# batch [117],Epoch going [1], Loss: 142.2309764623642
# batch [118],Epoch going [1], Loss: 143.54590594768524
# batch [119],Epoch going [1], Loss: 144.75820899009705
# batch [120],Epoch going [1], Loss: 145.96664810180664
# batch [121],Epoch going [1], Loss: 147.14958429336548
# batch [122],Epoch going [1], Loss: 148.38897359371185
# batch [123],Epoch going [1], Loss: 149.59486830234528
# ...
# batch [486],Epoch going [14], Loss: 557.6613298654556
# batch [487],Epoch going [14], Loss: 558.7463808059692
# batch [488],Epoch going [14], Loss: 559.9257029294968
# batch [489],Epoch going [14], Loss: 561.0665428638458
# batch [490],Epoch going [14], Loss: 562.1957216262817
# batch [491],Epoch going [14], Loss: 563.3333716392517
# batch [492],Epoch going [14], Loss: 564.4466509819031
# batch [493],Epoch going [14], Loss: 565.5578601360321
# batch [494],Epoch going [14], Loss: 566.6976326704025
# batch [495],Epoch going [14], Loss: 567.8552724123001
# batch [496],Epoch going [14], Loss: 569.0049450397491
# batch [497],Epoch going [14], Loss: 570.1620624065399
# batch [498],Epoch going [14], Loss: 571.3195774555206
# batch [499],Epoch going [14], Loss: 572.4276812076569
# batch [500],Epoch going [14], Loss: 573.5884370803833
# batch [501],Epoch going [14], Loss: 574.7160354852676
# batch [502],Epoch going [14], Loss: 575.8466584682465
# batch [503],Epoch going [14], Loss: 576.979395031929
# batch [504],Epoch going [14], Loss: 578.1361414194107
# batch [505],Epoch going [14], Loss: 579.2323364019394
# batch [506],Epoch going [14], Loss: 580.3805392980576
# batch [507],Epoch going [14], Loss: 581.5343248844147
# batch [508],Epoch going [14], Loss: 582.6772289276123
# batch [509],Epoch going [14], Loss: 583.7838933467865
# batch [510],Epoch going [14], Loss: 584.8847986459732
# batch [511],Epoch going [14], Loss: 586.0463328361511
# batch [512],Epoch going [14], Loss: 587.1815882921219
# batch [513],Epoch going [14], Loss: 588.2836948633194
# batch [514],Epoch going [14], Loss: 589.4696791172028
# batch [515],Epoch going [14], Loss: 590.5715630054474
# batch [516],Epoch going [14], Loss: 591.7343492507935
# batch [517],Epoch going [14], Loss: 592.9052267074585
# batch [518],Epoch going [14], Loss: 594.0966091156006
# batch [519],Epoch going [14], Loss: 595.2555727958679
# batch [520],Epoch going [14], Loss: 596.4311754703522
# batch [521],Epoch going [14], Loss: 597.5526595115662
# batch [522],Epoch going [14], Loss: 598.703247666359
# batch [523],Epoch going [14], Loss: 599.8501777648926
# batch [524],Epoch going [14], Loss: 601.0000402927399
# batch [525],Epoch going [14], Loss: 602.1534266471863
# batch [526],Epoch going [14], Loss: 603.3586268424988
# batch [527],Epoch going [14], Loss: 604.5093566179276
# batch [528],Epoch going [14], Loss: 605.6583265066147
# batch [529],Epoch going [14], Loss: 606.7962546348572
# batch [530],Epoch going [14], Loss: 607.897424697876
# batch [531],Epoch going [14], Loss: 608.9965872764587
# batch [532],Epoch going [14], Loss: 610.1376587152481
# batch [533],Epoch going [14], Loss: 611.2722781896591
# batch [534],Epoch going [14], Loss: 612.4156092405319
# batch [535],Epoch going [14], Loss: 613.5162326097488
# batch [536],Epoch going [14], Loss: 614.6540442705154
# batch [537],Epoch going [14], Loss: 615.7945358753204
# batch [538],Epoch going [14], Loss: 616.931548833847
# batch [539],Epoch going [14], Loss: 618.0560704469681
# batch [540],Epoch going [14], Loss: 619.1575597524643
# batch [541],Epoch going [14], Loss: 620.2931874990463
# batch [542],Epoch going [14], Loss: 621.4626852273941
# batch [543],Epoch going [14], Loss: 622.5873535871506
# batch [544],Epoch going [14], Loss: 623.6903955936432
# batch [545],Epoch going [14], Loss: 624.7723894119263
# batch [546],Epoch going [14], Loss: 625.9246423244476
# batch [547],Epoch going [14], Loss: 627.0488961935043
# batch [548],Epoch going [14], Loss: 628.2380937337875
# batch [549],Epoch going [14], Loss: 629.4524968862534
# batch [550],Epoch going [14], Loss: 630.5311614274979
# batch [551],Epoch going [14], Loss: 631.7520951032639
# batch [552],Epoch going [14], Loss: 632.9184781312943
# batch [553],Epoch going [14], Loss: 634.0990303754807
# batch [554],Epoch going [14], Loss: 635.2039674520493
# batch [555],Epoch going [14], Loss: 636.389629483223
# batch [556],Epoch going [14], Loss: 637.5337845087051
# batch [557],Epoch going [14], Loss: 638.6836507320404
# batch [558],Epoch going [14], Loss: 639.822447180748
# batch [559],Epoch going [14], Loss: 640.9855679273605
# batch [560],Epoch going [14], Loss: 642.1133998632431
# batch [561],Epoch going [14], Loss: 643.3103696107864
# batch [562],Epoch going [14], Loss: 644.4252265691757
# batch [563],Epoch going [14], Loss: 645.5705560445786
# batch [564],Epoch going [14], Loss: 646.7347860336304
# batch [565],Epoch going [14], Loss: 647.932479262352
# batch [566],Epoch going [14], Loss: 649.0837063789368
# batch [567],Epoch going [14], Loss: 650.1620261669159
# batch [568],Epoch going [14], Loss: 651.2930989265442
# batch [569],Epoch going [14], Loss: 652.4191519021988
# batch [570],Epoch going [14], Loss: 653.4729830026627
# batch [571],Epoch going [14], Loss: 654.5978704690933
# batch [572],Epoch going [14], Loss: 655.7478257417679
# batch [573],Epoch going [14], Loss: 656.8978214263916
# batch [574],Epoch going [14], Loss: 658.0300153493881
# batch [575],Epoch going [14], Loss: 659.1395114660263
# batch [576],Epoch going [14], Loss: 660.2660485506058
# batch [577],Epoch going [14], Loss: 661.3931571245193
# batch [578],Epoch going [14], Loss: 662.5098050832748
# batch [579],Epoch going [14], Loss: 663.5646344423294
# batch [580],Epoch going [14], Loss: 664.6775906085968
# batch [581],Epoch going [14], Loss: 665.8309862613678
# batch [582],Epoch going [14], Loss: 666.9970829486847
# batch [583],Epoch going [14], Loss: 668.1247148513794
# batch [584],Epoch going [14], Loss: 669.2493903636932
# batch [585],Epoch going [14], Loss: 670.3576238155365
# batch [586],Epoch going [14], Loss: 671.5000693798065
# batch [587],Epoch going [14], Loss: 672.6145482063293
# batch [588],Epoch going [14], Loss: 673.7628047466278
# batch [589],Epoch going [14], Loss: 674.9112455844879
# batch [590],Epoch going [14], Loss: 676.0358142852783
# batch [591],Epoch going [14], Loss: 677.1913993358612
# batch [592],Epoch going [14], Loss: 678.2685278654099
# batch [593],Epoch going [14], Loss: 679.4206124544144
# batch [594],Epoch going [14], Loss: 680.5106284618378
# batch [595],Epoch going [14], Loss: 681.6092100143433
# batch [596],Epoch going [14], Loss: 682.7856450080872
# batch [597],Epoch going [14], Loss: 683.8726224899292
# batch [598],Epoch going [14], Loss: 685.0048971176147
# batch [599],Epoch going [14], Loss: 686.1016099452972
# batch [600],Epoch going [14], Loss: 687.2097115516663
# batch [601],Epoch going [14], Loss: 688.3436490297318
# batch [602],Epoch going [14], Loss: 689.4435347318649
# batch [603],Epoch going [14], Loss: 690.6342904567719
# batch [604],Epoch going [14], Loss: 691.8222243785858
# batch [605],Epoch going [14], Loss: 692.9696686267853
# batch [606],Epoch going [14], Loss: 694.0952206850052
# batch [607],Epoch going [14], Loss: 695.2313269376755
# batch [608],Epoch going [14], Loss: 696.4047833681107
# batch [609],Epoch going [14], Loss: 697.5248254537582
# batch [610],Epoch going [14], Loss: 698.6490739583969
# batch [611],Epoch going [14], Loss: 699.8285697698593
# batch [612],Epoch going [14], Loss: 700.950946688652
# batch [613],Epoch going [14], Loss: 702.0869694948196
# batch [614],Epoch going [14], Loss: 703.2366317510605
# batch [615],Epoch going [14], Loss: 704.3785319328308
# batch [616],Epoch going [14], Loss: 705.5725905895233
# batch [617],Epoch going [14], Loss: 706.6893002986908
# batch [618],Epoch going [14], Loss: 707.8640974760056
# batch [619],Epoch going [14], Loss: 709.0114148855209
# batch [620],Epoch going [14], Loss: 710.0979928970337
# batch [621],Epoch going [14], Loss: 711.2254905700684
# batch [622],Epoch going [14], Loss: 712.4072605371475
# batch [623],Epoch going [14], Loss: 713.5855656862259
# batch [624],Epoch going [14], Loss: 714.7467812299728
# batch [625],Epoch going [14], Loss: 715.8902411460876
# batch [626],Epoch going [14], Loss: 717.0528287887573
# batch [627],Epoch going [14], Loss: 718.175127029419
# batch [628],Epoch going [14], Loss: 719.2284181118011
# batch [629],Epoch going [14], Loss: 720.3292211294174
# batch [630],Epoch going [14], Loss: 721.4640955924988
# batch [631],Epoch going [14], Loss: 722.537083864212
# batch [632],Epoch going [14], Loss: 723.6310013532639
# batch [633],Epoch going [14], Loss: 724.7650995254517
# batch [634],Epoch going [14], Loss: 725.8904421329498
# batch [635],Epoch going [14], Loss: 726.9877707958221
# batch [636],Epoch going [14], Loss: 728.157280087471
# batch [637],Epoch going [14], Loss: 729.2861505746841
# batch [638],Epoch going [14], Loss: 730.390741109848
# batch [639],Epoch going [14], Loss: 731.4496693611145
# batch [640],Epoch going [14], Loss: 732.58234167099
# batch [641],Epoch going [14], Loss: 733.695515871048
# batch [642],Epoch going [14], Loss: 734.7705550193787
# batch [643],Epoch going [14], Loss: 735.9001439809799
# batch [644],Epoch going [14], Loss: 737.0538567304611
# batch [645],Epoch going [14], Loss: 738.2210195064545
# batch [646],Epoch going [14], Loss: 739.3536039590836
# batch [647],Epoch going [14], Loss: 740.4262125492096
# batch [648],Epoch going [14], Loss: 741.5944777727127
# batch [649],Epoch going [14], Loss: 742.7333390712738
# batch [650],Epoch going [14], Loss: 743.8584697246552
# batch [651],Epoch going [14], Loss: 745.034085392952
# batch [652],Epoch going [14], Loss: 746.1961371898651
# batch [653],Epoch going [14], Loss: 747.2658540010452
# batch [654],Epoch going [14], Loss: 748.4209553003311
# batch [655],Epoch going [14], Loss: 749.5779945850372
# batch [656],Epoch going [14], Loss: 750.7101137638092
# batch [657],Epoch going [14], Loss: 751.8665101528168
# batch [658],Epoch going [14], Loss: 753.0190992355347
# batch [659],Epoch going [14], Loss: 754.1294548511505
# batch [660],Epoch going [14], Loss: 755.263139128685
# batch [661],Epoch going [14], Loss: 756.4335488080978
# batch [662],Epoch going [14], Loss: 757.5802072286606
# batch [663],Epoch going [14], Loss: 758.6998339891434
# batch [664],Epoch going [14], Loss: 759.8797382116318
# batch [665],Epoch going [14], Loss: 761.0421155691147
# batch [666],Epoch going [14], Loss: 762.1915936470032
# batch [667],Epoch going [14], Loss: 763.2877666950226
# batch [668],Epoch going [14], Loss: 764.4571610689163
# batch [669],Epoch going [14], Loss: 765.5806622505188
# batch [670],Epoch going [14], Loss: 766.745215177536
# batch [671],Epoch going [14], Loss: 767.9012906551361
# batch [672],Epoch going [14], Loss: 769.0117750167847
# batch [673],Epoch going [14], Loss: 770.0961492061615
# batch [674],Epoch going [14], Loss: 771.2567713260651
# batch [675],Epoch going [14], Loss: 772.3598668575287
# batch [676],Epoch going [14], Loss: 773.51895570755
# batch [677],Epoch going [14], Loss: 774.6679539680481
# batch [678],Epoch going [14], Loss: 775.7665393352509
# batch [679],Epoch going [14], Loss: 776.9519348144531
# batch [680],Epoch going [14], Loss: 778.1046206951141
# batch [681],Epoch going [14], Loss: 779.2057211399078
# batch [682],Epoch going [14], Loss: 780.2948825359344
# batch [683],Epoch going [14], Loss: 781.462760925293
# batch [684],Epoch going [14], Loss: 782.6022833585739
# batch [685],Epoch going [14], Loss: 783.734327673912
# batch [686],Epoch going [14], Loss: 784.8532316684723
# batch [687],Epoch going [14], Loss: 785.9810214042664
# batch [688],Epoch going [14], Loss: 787.1614819765091
# batch [689],Epoch going [14], Loss: 788.3075121641159
# batch [690],Epoch going [14], Loss: 789.4351983070374
# batch [691],Epoch going [14], Loss: 790.5533610582352
# batch [692],Epoch going [14], Loss: 791.682453751564
# batch [693],Epoch going [14], Loss: 792.7969032526016
# batch [694],Epoch going [14], Loss: 793.9561887979507
# batch [695],Epoch going [14], Loss: 795.1246385574341
# batch [696],Epoch going [14], Loss: 796.2435065507889
# batch [697],Epoch going [14], Loss: 797.347887635231
# batch [698],Epoch going [14], Loss: 798.4983507394791
# batch [699],Epoch going [14], Loss: 799.5983762741089
# batch [700],Epoch going [14], Loss: 800.7011284828186
# batch [701],Epoch going [14], Loss: 801.7867918014526
# batch [702],Epoch going [14], Loss: 802.8817253112793
# batch [703],Epoch going [14], Loss: 804.0218646526337
# batch [704],Epoch going [14], Loss: 805.147274851799
# batch [705],Epoch going [14], Loss: 806.2439707517624
# batch [706],Epoch going [14], Loss: 807.4024041891098
# batch [707],Epoch going [14], Loss: 808.5124316215515
# batch [708],Epoch going [14], Loss: 809.6612479686737
# batch [709],Epoch going [14], Loss: 810.8642463684082
# batch [710],Epoch going [14], Loss: 811.9838163852692
# batch [711],Epoch going [14], Loss: 813.1593334674835
# batch [712],Epoch going [14], Loss: 814.3514287471771
# batch [713],Epoch going [14], Loss: 815.4840259552002
# batch [714],Epoch going [14], Loss: 816.687619805336
# batch [715],Epoch going [14], Loss: 817.7938237190247
# batch [716],Epoch going [14], Loss: 819.0145488977432
# batch [717],Epoch going [14], Loss: 820.1340457201004
# batch [718],Epoch going [14], Loss: 821.272207736969
# batch [719],Epoch going [14], Loss: 822.4157762527466
# batch [720],Epoch going [14], Loss: 823.5704820156097
# batch [721],Epoch going [14], Loss: 824.6856768131256
# batch [722],Epoch going [14], Loss: 825.7739908695221
# batch [723],Epoch going [14], Loss: 826.9378658533096
# batch [724],Epoch going [14], Loss: 828.0389820337296
# batch [725],Epoch going [14], Loss: 829.1984558105469
# batch [726],Epoch going [14], Loss: 830.3253362178802
# batch [727],Epoch going [14], Loss: 831.4447796344757
# batch [728],Epoch going [14], Loss: 832.6447860002518
# batch [729],Epoch going [14], Loss: 833.7813590764999
# batch [730],Epoch going [14], Loss: 834.8947509527206
# batch [731],Epoch going [14], Loss: 836.0919753313065
# batch [732],Epoch going [14], Loss: 837.2354136705399
# batch [733],Epoch going [14], Loss: 838.3640838861465
# batch [734],Epoch going [14], Loss: 839.474608540535
# batch [735],Epoch going [14], Loss: 840.556803226471
# batch [736],Epoch going [14], Loss: 841.653645992279
# batch [737],Epoch going [14], Loss: 842.8202197551727
# batch [738],Epoch going [14], Loss: 843.9646781682968
# batch [739],Epoch going [14], Loss: 845.0377916097641
# batch [740],Epoch going [14], Loss: 846.1954354047775
# batch [741],Epoch going [14], Loss: 847.3124731779099
# batch [742],Epoch going [14], Loss: 848.4509521722794
# batch [743],Epoch going [14], Loss: 849.6318944692612
# batch [744],Epoch going [14], Loss: 850.7523304224014
# batch [745],Epoch going [14], Loss: 851.8371473550797
# batch [746],Epoch going [14], Loss: 852.92527115345
# batch [747],Epoch going [14], Loss: 854.0727083683014
# batch [748],Epoch going [14], Loss: 855.1669788360596
# batch [749],Epoch going [14], Loss: 856.3175828456879
# batch [750],Epoch going [14], Loss: 857.4424160718918
# batch [751],Epoch going [14], Loss: 858.5551203489304
# batch [752],Epoch going [14], Loss: 859.6908172369003
# batch [753],Epoch going [14], Loss: 860.7840399742126
# batch [754],Epoch going [14], Loss: 861.9069347381592
# batch [755],Epoch going [14], Loss: 863.0545971393585
# batch [756],Epoch going [14], Loss: 864.1907268762589
# batch [757],Epoch going [14], Loss: 865.324982047081
# batch [758],Epoch going [14], Loss: 866.4760475158691
# batch [759],Epoch going [14], Loss: 867.6321153640747
# batch [760],Epoch going [14], Loss: 868.7506574392319
# batch [761],Epoch going [14], Loss: 869.8616677522659
# batch [762],Epoch going [14], Loss: 870.9860444068909
# batch [763],Epoch going [14], Loss: 872.1361918449402
# batch [764],Epoch going [14], Loss: 873.2957890033722
# batch [765],Epoch going [14], Loss: 874.4298009872437
# batch [766],Epoch going [14], Loss: 875.588431596756
# batch [767],Epoch going [14], Loss: 876.7212253808975
# batch [768],Epoch going [14], Loss: 877.8900059461594
# batch [769],Epoch going [14], Loss: 879.0068957805634
# batch [770],Epoch going [14], Loss: 880.1438566446304
# batch [771],Epoch going [14], Loss: 881.2960096597672
# batch [772],Epoch going [14], Loss: 882.4049351215363
# batch [773],Epoch going [14], Loss: 883.5016000270844
# batch [774],Epoch going [14], Loss: 884.644583940506
# batch [775],Epoch going [14], Loss: 885.7402683496475
# batch [776],Epoch going [14], Loss: 886.8222008943558
# batch [777],Epoch going [14], Loss: 887.9919544458389
# batch [778],Epoch going [14], Loss: 889.1230595111847
# batch [779],Epoch going [14], Loss: 890.264520406723
# batch [780],Epoch going [14], Loss: 891.4262406826019
# batch [781],Epoch going [14], Loss: 892.6292395591736
# epoch[15/15], Loss: 1.1415

# %%
# Initialize parameters for the linear layer
num_features = 512  # This is typical for ResNet-18's final layer output
num_classes = 10
linear_layer = nn.Linear(num_features, num_classes).to(device)

# Optimizer for the linear layer
optimizer = torch.optim.Adam(linear_layer.parameters(), lr=0.001)

# %%
def apply_linear_classifier(features, linear_layer):
    return linear_layer(features)

# %%
criterion = nn.CrossEntropyLoss()
outputs=[]
for epoch in range(num_epochs):
    total_loss = 0
    correct = 0
    total = 0
    
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        # Assuming 'resnet_model' is your pre-trained ResNet model and it's already loaded
        with torch.no_grad():
            features = resnet_model(images)
        
        # Reset gradient
        optimizer.zero_grad()
        
        # Apply linear classifier
        outputs = apply_linear_classifier(features, linear_layer)
        
        # Calculate loss
        loss = criterion(outputs, labels)
        loss.backward()
        
        # Update weights
        optimizer.step()
        
        total_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    # Print statistics
    print(f"Epoch [{epoch+1}/{num_epochs}] Loss: {total_loss / len(train_loader):.4f} Acc: {100 * correct / total:.2f}%")
# Out:
# Epoch [1/15] Loss: 1.9679 Acc: 27.76%
# Epoch [2/15] Loss: 1.9711 Acc: 27.79%
# Epoch [3/15] Loss: 1.9692 Acc: 27.96%
# Epoch [4/15] Loss: 1.9698 Acc: 27.92%
# Epoch [5/15] Loss: 1.9674 Acc: 28.06%
# Epoch [6/15] Loss: 1.9662 Acc: 28.13%
# Epoch [7/15] Loss: 1.9665 Acc: 28.02%
# Epoch [8/15] Loss: 1.9685 Acc: 28.11%
# Epoch [9/15] Loss: 1.9638 Acc: 27.90%
# Epoch [10/15] Loss: 1.9650 Acc: 28.17%
# Epoch [11/15] Loss: 1.9685 Acc: 27.81%
# Epoch [12/15] Loss: 1.9706 Acc: 27.99%
# Epoch [13/15] Loss: 1.9675 Acc: 27.85%
# Epoch [14/15] Loss: 1.9635 Acc: 28.28%
# Epoch [15/15] Loss: 1.9661 Acc: 27.83%

# %%
# Define the path where you want to save the model
model_save_path_linear = 'linear_classifier_2.pth'

# Save the model state dictionary
torch.save(linear_layer.state_dict(),model_save_path_linear)

# %%
# Save model and optimizer state
checkpoint_linear = {
    'model_state_dict': linear_layer.state_dict(),
    'optimizer_state_dict': optimizer.state_dict()
}
torch.save(checkpoint_linear, 'linear_classifier_checkpoint_2.pth')

# %%
def load_checkpoint(model_path, model, optimizer):
    checkpoint = torch.load(model_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    return model, optimizer

# Assuming the classifier and optimizer have been defined:
num_features = 512  # Assuming this is known
num_classes = 10    # For CIFAR-10
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

classifier = nn.Linear(num_features, num_classes).to(device)
optimizer = optim.Adam(classifier.parameters(), lr=0.001)

# Load model and optimizer from checkpoint
classifier, optimizer = load_checkpoint('linear_classifier_checkpoint_2.pth', classifier, optimizer)

# %%
# Assuming num_features and num_classes are known
num_features = 512  # Example feature size from a ResNet18 model
num_classes = 10    # Number of classes for CIFAR-10

# Define the classifier structure
classifier = nn.Linear(num_features, num_classes)
checkpoint_check = torch.load('linear_classifier_checkpoint_2.pth')

# Correctly load the model's state dictionary
classifier.load_state_dict(checkpoint_check['model_state_dict'])

# Assuming you are using a GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
classifier.to(device)
# Out:
# Linear(in_features=512, out_features=10, bias=True)

# %%
print("Classifier Summary:")
print(f"Input features: 512")
print(f"Output features: 10")
print(f"Number of parameters: {sum(p.numel() for p in classifier.parameters() if p.requires_grad)}")
# Out:
# Classifier Summary:
# Input features: 512
# Output features: 10
# Number of parameters: 5130

# %%
test_transform = transforms.Compose([
    transforms.ToTensor()
])

# %%
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True,transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=28, shuffle=False, num_workers=4)
test_size = len(test_dataset)
print(f"Size of the test set: {test_size} samples")
# Out:
# Files already downloaded and verified
# Size of the test set: 10000 samples

# %%
def test_model(model, test_loader, criterion):
    model.eval()  # Set the model to evaluation mode
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    total_loss_test = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss_test += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = correct / total
    avg_loss = total_loss / len(test_loader)
    print(f"loss on test set: {total_loss_test:.4f}")
    return accuracy, avg_loss

# %%
from sklearn.metrics import accuracy_score
criterion = nn.CrossEntropyLoss()
test_accuracy,test_avg_loss = test_model(resnet_model, test_loader,criterion)
print(f"Accuracy on test set: {test_accuracy:.4f}")
# Out:
# loss on test set: 2455.1657
# Accuracy on test set: 0.0022

# %%
pretrained_dict = torch.load('resnet_simclr_checkpoint.pth')
pretrained_model = pretrained_dict['model_state_dict']
pretrained_model.fc = nn.Identity()

# %%
print(pretrained_dict.keys())
# Out:
# dict_keys(['epoch', 'model_state_dict', 'optimizer_state_dict', 'loss'])

# %%
from torchsummary import summary
resnet_model.load_state_dict(pretrained_model)
# Assuming 'pretrained_model' is your pretrained model object
summary(resnet_model, input_size=(3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 16, 16]           9,408
#        BatchNorm2d-2           [-1, 64, 16, 16]             128
#               ReLU-3           [-1, 64, 16, 16]               0
#          MaxPool2d-4             [-1, 64, 8, 8]               0
#             Conv2d-5             [-1, 64, 8, 8]          36,864
#        BatchNorm2d-6             [-1, 64, 8, 8]             128
#               ReLU-7             [-1, 64, 8, 8]               0
#             Conv2d-8             [-1, 64, 8, 8]          36,864
#        BatchNorm2d-9             [-1, 64, 8, 8]             128
#              ReLU-10             [-1, 64, 8, 8]               0
#        BasicBlock-11             [-1, 64, 8, 8]               0
#            Conv2d-12             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-13             [-1, 64, 8, 8]             128
#              ReLU-14             [-1, 64, 8, 8]               0
#            Conv2d-15             [-1, 64, 8, 8]          36,864
#       BatchNorm2d-16             [-1, 64, 8, 8]             128
#              ReLU-17             [-1, 64, 8, 8]               0
#        BasicBlock-18             [-1, 64, 8, 8]               0
#            Conv2d-19            [-1, 128, 4, 4]          73,728
#       BatchNorm2d-20            [-1, 128, 4, 4]             256
#              ReLU-21            [-1, 128, 4, 4]               0
#            Conv2d-22            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-23            [-1, 128, 4, 4]             256
#            Conv2d-24            [-1, 128, 4, 4]           8,192
#       BatchNorm2d-25            [-1, 128, 4, 4]             256
#              ReLU-26            [-1, 128, 4, 4]               0
#        BasicBlock-27            [-1, 128, 4, 4]               0
#            Conv2d-28            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-29            [-1, 128, 4, 4]             256
#              ReLU-30            [-1, 128, 4, 4]               0
#            Conv2d-31            [-1, 128, 4, 4]         147,456
#       BatchNorm2d-32            [-1, 128, 4, 4]             256
#              ReLU-33            [-1, 128, 4, 4]               0
#        BasicBlock-34            [-1, 128, 4, 4]               0
#            Conv2d-35            [-1, 256, 2, 2]         294,912
#       BatchNorm2d-36            [-1, 256, 2, 2]             512
#              ReLU-37            [-1, 256, 2, 2]               0
#            Conv2d-38            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-39            [-1, 256, 2, 2]             512
#            Conv2d-40            [-1, 256, 2, 2]          32,768
#       BatchNorm2d-41            [-1, 256, 2, 2]             512
#              ReLU-42            [-1, 256, 2, 2]               0
#        BasicBlock-43            [-1, 256, 2, 2]               0
#            Conv2d-44            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-45            [-1, 256, 2, 2]             512
#              ReLU-46            [-1, 256, 2, 2]               0
#            Conv2d-47            [-1, 256, 2, 2]         589,824
#       BatchNorm2d-48            [-1, 256, 2, 2]             512
#              ReLU-49            [-1, 256, 2, 2]               0
#        BasicBlock-50            [-1, 256, 2, 2]               0
#            Conv2d-51            [-1, 512, 1, 1]       1,179,648
#       BatchNorm2d-52            [-1, 512, 1, 1]           1,024
#              ReLU-53            [-1, 512, 1, 1]               0
#            Conv2d-54            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-55            [-1, 512, 1, 1]           1,024
#            Conv2d-56            [-1, 512, 1, 1]         131,072
#       BatchNorm2d-57            [-1, 512, 1, 1]           1,024
#              ReLU-58            [-1, 512, 1, 1]               0
#        BasicBlock-59            [-1, 512, 1, 1]               0
#            Conv2d-60            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-61            [-1, 512, 1, 1]           1,024
#              ReLU-62            [-1, 512, 1, 1]               0
#            Conv2d-63            [-1, 512, 1, 1]       2,359,296
#       BatchNorm2d-64            [-1, 512, 1, 1]           1,024
#              ReLU-65            [-1, 512, 1, 1]               0
#        BasicBlock-66            [-1, 512, 1, 1]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#          Identity-68                  [-1, 512]               0
# ================================================================
# Total params: 11,176,512
# Trainable params: 11,176,512
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.29
# Params size (MB): 42.64
# Estimated Total Size (MB): 43.94
# ----------------------------------------------------------------

# %%
if 'fc' in pretrained_model:
    del pretrained_model['fc']

# %%
trained_model = resnet_model  # Replace YourModel() with the class name of your model
trained_model.load_state_dict(pretrained_model)
# Out:
# <All keys matched successfully>

# %%
state_dict_keys = trained_model.state_dict().keys()
print(state_dict_keys)
# Out:
# odict_keys(['conv1.weight', 'bn1.weight', 'bn1.bias', 'bn1.running_mean', 'bn1.running_var', 'bn1.num_batches_tracked', 'layer1.0.conv1.weight', 'layer1.0.bn1.weight', 'layer1.0.bn1.bias', 'layer1.0.bn1.running_mean', 'layer1.0.bn1.running_var', 'layer1.0.bn1.num_batches_tracked', 'layer1.0.conv2.weight', 'layer1.0.bn2.weight', 'layer1.0.bn2.bias', 'layer1.0.bn2.running_mean', 'layer1.0.bn2.running_var', 'layer1.0.bn2.num_batches_tracked', 'layer1.1.conv1.weight', 'layer1.1.bn1.weight', 'layer1.1.bn1.bias', 'layer1.1.bn1.running_mean', 'layer1.1.bn1.running_var', 'layer1.1.bn1.num_batches_tracked', 'layer1.1.conv2.weight', 'layer1.1.bn2.weight', 'layer1.1.bn2.bias', 'layer1.1.bn2.running_mean', 'layer1.1.bn2.running_var', 'layer1.1.bn2.num_batches_tracked', 'layer2.0.conv1.weight', 'layer2.0.bn1.weight', 'layer2.0.bn1.bias', 'layer2.0.bn1.running_mean', 'layer2.0.bn1.running_var', 'layer2.0.bn1.num_batches_tracked', 'layer2.0.conv2.weight', 'layer2.0.bn2.weight', 'layer2.0.bn2.bias', 'layer2.0.bn2.running_mean', 'layer2.0.bn2.running_var', 'layer2.0.bn2.num_batches_tracked', 'layer2.0.downsample.0.weight', 'layer2.0.downsample.1.weight', 'layer2.0.downsample.1.bias', 'layer2.0.downsample.1.running_mean', 'layer2.0.downsample.1.running_var', 'layer2.0.downsample.1.num_batches_tracked', 'layer2.1.conv1.weight', 'layer2.1.bn1.weight', 'layer2.1.bn1.bias', 'layer2.1.bn1.running_mean', 'layer2.1.bn1.running_var', 'layer2.1.bn1.num_batches_tracked', 'layer2.1.conv2.weight', 'layer2.1.bn2.weight', 'layer2.1.bn2.bias', 'layer2.1.bn2.running_mean', 'layer2.1.bn2.running_var', 'layer2.1.bn2.num_batches_tracked', 'layer3.0.conv1.weight', 'layer3.0.bn1.weight', 'layer3.0.bn1.bias', 'layer3.0.bn1.running_mean', 'layer3.0.bn1.running_var', 'layer3.0.bn1.num_batches_tracked', 'layer3.0.conv2.weight', 'layer3.0.bn2.weight', 'layer3.0.bn2.bias', 'layer3.0.bn2.running_mean', 'layer3.0.bn2.running_var', 'layer3.0.bn2.num_batches_tracked', 'layer3.0.downsample.0.weight', 'layer3.0.downsample.1.weight', 'layer3.0.downsample.1.bias', 'layer3.0.downsample.1.running_mean', 'layer3.0.downsample.1.running_var', 'layer3.0.downsample.1.num_batches_tracked', 'layer3.1.conv1.weight', 'layer3.1.bn1.weight', 'layer3.1.bn1.bias', 'layer3.1.bn1.running_mean', 'layer3.1.bn1.running_var', 'layer3.1.bn1.num_batches_tracked', 'layer3.1.conv2.weight', 'layer3.1.bn2.weight', 'layer3.1.bn2.bias', 'layer3.1.bn2.running_mean', 'layer3.1.bn2.running_var', 'layer3.1.bn2.num_batches_tracked', 'layer4.0.conv1.weight', 'layer4.0.bn1.weight', 'layer4.0.bn1.bias', 'layer4.0.bn1.running_mean', 'layer4.0.bn1.running_var', 'layer4.0.bn1.num_batches_tracked', 'layer4.0.conv2.weight', 'layer4.0.bn2.weight', 'layer4.0.bn2.bias', 'layer4.0.bn2.running_mean', 'layer4.0.bn2.running_var', 'layer4.0.bn2.num_batches_tracked', 'layer4.0.downsample.0.weight', 'layer4.0.downsample.1.weight', 'layer4.0.downsample.1.bias', 'layer4.0.downsample.1.running_mean', 'layer4.0.downsample.1.running_var', 'layer4.0.downsample.1.num_batches_tracked', 'layer4.1.conv1.weight', 'layer4.1.bn1.weight', 'layer4.1.bn1.bias', 'layer4.1.bn1.running_mean', 'layer4.1.bn1.running_var', 'layer4.1.bn1.num_batches_tracked', 'layer4.1.conv2.weight', 'layer4.1.bn2.weight', 'layer4.1.bn2.bias', 'layer4.1.bn2.running_mean', 'layer4.1.bn2.running_var', 'layer4.1.bn2.num_batches_tracked'])

# %%
#print(trained_model)

# Check if there's a classification layer in the forward method


# Check if there's a classification layer in the named modules of the model
print("Modules:")
for name, module in trained_model.named_modules():
    print(name, module)
# Out:
# Modules:
#  ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Identity()
# )
# conv1 Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# bn1 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# relu ReLU(inplace=True)
# maxpool MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# layer1 Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# layer1.0 BasicBlock(
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# layer1.0.conv1 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# layer1.0.bn1 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer1.0.relu ReLU(inplace=True)
# layer1.0.conv2 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# layer1.0.bn2 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer1.1 BasicBlock(
#   (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# layer1.1.conv1 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# layer1.1.bn1 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer1.1.relu ReLU(inplace=True)
# layer1.1.conv2 Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# layer1.1.bn2 BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer2 Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# layer2.0 BasicBlock(
#   (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (downsample): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# layer2.0.conv1 Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# layer2.0.bn1 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer2.0.relu ReLU(inplace=True)
# layer2.0.conv2 Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# layer2.0.bn2 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer2.0.downsample Sequential(
#   (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# layer2.0.downsample.0 Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
# layer2.0.downsample.1 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer2.1 BasicBlock(
#   (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# layer2.1.conv1 Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# layer2.1.bn1 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer2.1.relu ReLU(inplace=True)
# layer2.1.conv2 Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# layer2.1.bn2 BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer3 Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# layer3.0 BasicBlock(
#   (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (downsample): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# layer3.0.conv1 Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# layer3.0.bn1 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer3.0.relu ReLU(inplace=True)
# layer3.0.conv2 Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# layer3.0.bn2 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer3.0.downsample Sequential(
#   (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# layer3.0.downsample.0 Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
# layer3.0.downsample.1 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer3.1 BasicBlock(
#   (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# layer3.1.conv1 Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# layer3.1.bn1 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer3.1.relu ReLU(inplace=True)
# layer3.1.conv2 Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# layer3.1.bn2 BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer4 Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# layer4.0 BasicBlock(
#   (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (downsample): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# layer4.0.conv1 Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# layer4.0.bn1 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer4.0.relu ReLU(inplace=True)
# layer4.0.conv2 Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# layer4.0.bn2 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer4.0.downsample Sequential(
#   (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#   (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# layer4.0.downsample.0 Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
# layer4.0.downsample.1 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer4.1 BasicBlock(
#   (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )
# layer4.1.conv1 Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# layer4.1.bn1 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# layer4.1.relu ReLU(inplace=True)
# layer4.1.conv2 Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# layer4.1.bn2 BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# avgpool AdaptiveAvgPool2d(output_size=(1, 1))
# fc Identity()
